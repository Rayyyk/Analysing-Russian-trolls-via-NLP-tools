# %% [markdown]
# #  COMP4560 - Artefact
# ## Implementation of Supervised Topic model
#
#
# Bokun Kong, u6342099
#
# Supervisor: Dr. Dongwoo Kim
#
# This jupyter notebook file is created by Bokun Kong.
#
#
# * Dataset of Russian troll: https://github.com/fivethirtyeight/russian-troll-tweets/
# * Dataset for sentiment analysis: https://www.kaggle.com/kazanova/sentiment140
# * sLDA model is created by Dr. Dongwoo Kim: https://github.com/dongwookim-ml/python-topic-model/tree/master/ptm
# * Sentiment analysis is based on: https://towardsdatascience.com/basic-binary-sentiment-analysis-using-nltk-c94ba17ae386

# %%
# Import libraries
import numpy as np
import pandas as pd
import glob
import string

import nltk
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import WordNetLemmatizer, SnowballStemmer

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora

# Import supervised topic model algorithm
import logging
from ptm import GibbsSupervisedLDA
from ptm.utils import get_top_words

logger = logging.getLogger('GibbsSupervisedLDA')
logger.propagate = False

# %%
# Reading training files and extract useful information
allfiles = glob.glob('training dataset/IRAhandle_tweets_*.csv')
allfiles.sort()

data = pd.concat([pd.read_csv(f) for f in allfiles], ignore_index = True)
print('Number of rows and columns of the whole dataset: {}'.format(data.shape))

df_en = data[(data['language'] == 'English') & (data['account_category'] != 'NonEnglish') & (~data['content'].isnull())]
df_lnr = df_en[((df_en['account_category'] == 'LeftTroll') | (df_en['account_category'] == 'RightTroll'))]
df_lnr = df_lnr.reset_index(drop=True)
# Creat a new training dataset containing useful tweets
df_lnr.to_csv("left_right_news.csv", index=False)


# Reading testing files and extract useful information
allfiles = glob.glob('testing dataset/IRAhandle_tweets_*.csv')
allfiles.sort()

testing_data = pd.concat([pd.read_csv(f) for f in allfiles], ignore_index = True)
print('Number of rows and columns of the whole dataset: {}'.format(testing_data.shape))

df_en = testing_data[(testing_data['language'] == 'English') & (testing_data['account_category'] != 'NonEnglish') & (~testing_data['content'].isnull())]
df_lnr = df_en[((df_en['account_category'] == 'LeftTroll') | (df_en['account_category'] == 'RightTroll'))]
df_lnr = df_lnr.reset_index(drop=True)
# Creat a new testing dataset containing useful tweets
df_lnr.to_csv("testing_left_right_news.csv", index=False)

# %%
# Read the generated dataset
df_tweets = pd.read_csv("left_right_news.csv", parse_dates=['publish_date'])
df_tweets = df_tweets.drop(['external_author_id', 'author', 'region', 'language', 'harvested_date', 'following', 'followers', 'updates', 'post_type', 'account_type', 'retweet', 'new_june_2018', 'alt_external_id', 'article_url', 'tco1_step1', 'tco2_step1', 'tco3_step1', 'tweet_id'], axis=1)
df_tweets['index'] = df_tweets.index
df_tweets.shape

# Numerating the troll category 
ratings =  df_tweets.drop(['content', 'publish_date', 'index'], axis=1)
for i in range(len(df_tweets)):
    if ratings.loc[i, 'account_category'] == 'LeftTroll':
        ratings.loc[i, 'account_category'] = -1
    elif ratings.loc[i, 'account_category'] == 'RightTroll':
        ratings.loc[i, 'account_category'] = 1

ratings = ratings.values.flatten()
# Out:
# D:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Read the generated dataset
test_df_tweets = pd.read_csv("testing_left_right_news.csv", parse_dates=['publish_date'])
test_df_tweets = test_df_tweets.drop(['external_author_id', 'author', 'region', 'language', 'harvested_date', 'following', 'followers', 'updates', 'post_type', 'account_type', 'retweet', 'new_june_2018', 'alt_external_id', 'article_url', 'tco1_step1', 'tco2_step1', 'tco3_step1', 'tweet_id'], axis=1)
test_df_tweets['index'] = test_df_tweets.index
test_df_tweets.shape

# Numerating the troll category 
test_ratings =  test_df_tweets.drop(['content', 'publish_date', 'index'], axis=1)
for i in range(len(test_df_tweets)):
    if test_ratings.loc[i, 'account_category'] == 'LeftTroll':
        test_ratings.loc[i, 'account_category'] = -1
    elif test_ratings.loc[i, 'account_category'] == 'RightTroll':
        test_ratings.loc[i, 'account_category'] = 1
    
test_ratings = test_ratings.values.flatten()

# %%
# Data pre-processing
punctuation = set(string.punctuation)
stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

def preprocessor(text):
    tokens = WordPunctTokenizer().tokenize(text.lower())
    stems = []
    for token in tokens:
        if token.isalpha() and token not in gensim.parsing.preprocessing.STOPWORDS and token not in punctuation and len(token) >= 3 and len(token) <= 14:
            stems.append(lemmatizer.lemmatize(token, pos='v'))
   
    return stems

docs = df_tweets['content'].map(preprocessor)
test_docs = test_df_tweets['content'].map(preprocessor)

# %%
# Creating dictionary for corpus
dictionary = corpora.Dictionary(docs)
dictionary.filter_n_most_frequent(50)
dictionary.filter_extremes(no_below=6, keep_n=100000)
# Generate Document-Term matrix
doc_term_matrix = [dictionary.doc2bow(doc) for doc in docs]

# %%
# sLDA parameter setting
n_doc = len(doc_term_matrix)
n_voca = len(dictionary)

# %%
# Building corpus for sLDA input
corpus = []
for i in range(n_doc):
    corp = []
    for j in range(len(doc_term_matrix[i])):
        for x in range(doc_term_matrix[i][j][1]):
            
            corp.append(doc_term_matrix[i][j][0])
    corpus.append(corp)

# %%
n_topic = 20
r_var = 0.01
# Training the sLDA model
model = GibbsSupervisedLDA(n_doc, n_voca, n_topic, sigma=r_var)
model.fit(corpus, ratings)
# Out:
# 2019-09-06 23:03:06 INFO:GibbsSupervisedLDA:[ITER] 0,	MAE:0.11,	log_likelihood:-70488781.66
# 2019-09-06 23:08:12 INFO:GibbsSupervisedLDA:[ITER] 1,	MAE:0.11,	log_likelihood:-69348952.23
# 2019-09-06 23:13:18 INFO:GibbsSupervisedLDA:[ITER] 2,	MAE:0.10,	log_likelihood:-68628204.19
# 2019-09-06 23:19:24 INFO:GibbsSupervisedLDA:[ITER] 3,	MAE:0.10,	log_likelihood:-68093516.49
# 2019-09-06 23:25:31 INFO:GibbsSupervisedLDA:[ITER] 4,	MAE:0.10,	log_likelihood:-67726352.70
# 2019-09-06 23:32:02 INFO:GibbsSupervisedLDA:[ITER] 5,	MAE:0.10,	log_likelihood:-67371376.17
# 2019-09-06 23:38:33 INFO:GibbsSupervisedLDA:[ITER] 6,	MAE:0.10,	log_likelihood:-67076275.12
# 2019-09-06 23:45:03 INFO:GibbsSupervisedLDA:[ITER] 7,	MAE:0.10,	log_likelihood:-66837805.20
# 2019-09-06 23:51:22 INFO:GibbsSupervisedLDA:[ITER] 8,	MAE:0.10,	log_likelihood:-66615324.68
# 2019-09-06 23:57:42 INFO:GibbsSupervisedLDA:[ITER] 9,	MAE:0.10,	log_likelihood:-66410363.04
# 2019-09-07 00:04:14 INFO:GibbsSupervisedLDA:[ITER] 10,	MAE:0.10,	log_likelihood:-66220477.07
# 2019-09-07 00:10:43 INFO:GibbsSupervisedLDA:[ITER] 11,	MAE:0.10,	log_likelihood:-66038531.82
# 2019-09-07 00:17:14 INFO:GibbsSupervisedLDA:[ITER] 12,	MAE:0.10,	log_likelihood:-65857413.31
# 2019-09-07 00:23:46 INFO:GibbsSupervisedLDA:[ITER] 13,	MAE:0.10,	log_likelihood:-65685357.44
# 2019-09-07 00:29:04 INFO:GibbsSupervisedLDA:[ITER] 14,	MAE:0.10,	log_likelihood:-65513244.58
# 2019-09-07 00:34:06 INFO:GibbsSupervisedLDA:[ITER] 15,	MAE:0.10,	log_likelihood:-65336645.35
# 2019-09-07 00:39:08 INFO:GibbsSupervisedLDA:[ITER] 16,	MAE:0.10,	log_likelihood:-65165325.38
# 2019-09-07 00:44:11 INFO:GibbsSupervisedLDA:[ITER] 17,	MAE:0.10,	log_likelihood:-64993269.76
# 2019-09-07 00:49:12 INFO:GibbsSupervisedLDA:[ITER] 18,	MAE:0.10,	log_likelihood:-64826397.60
# 2019-09-07 00:54:14 INFO:GibbsSupervisedLDA:[ITER] 19,	MAE:0.10,	log_likelihood:-64649890.33
# 2019-09-07 00:59:17 INFO:GibbsSupervisedLDA:[ITER] 20,	MAE:0.10,	log_likelihood:-64476128.63
# 2019-09-07 01:04:20 INFO:GibbsSupervisedLDA:[ITER] 21,	MAE:0.10,	log_likelihood:-64300159.63
# 2019-09-07 01:09:22 INFO:GibbsSupervisedLDA:[ITER] 22,	MAE:0.10,	log_likelihood:-64125034.97
# 2019-09-07 01:14:25 INFO:GibbsSupervisedLDA:[ITER] 23,	MAE:0.10,	log_likelihood:-63952503.69
# 2019-09-07 01:19:28 INFO:GibbsSupervisedLDA:[ITER] 24,	MAE:0.10,	log_likelihood:-63786499.59
# 2019-09-07 01:24:30 INFO:GibbsSupervisedLDA:[ITER] 25,	MAE:0.10,	log_likelihood:-63619270.26
# 2019-09-07 01:29:31 INFO:GibbsSupervisedLDA:[ITER] 26,	MAE:0.10,	log_likelihood:-63456175.93
# 2019-09-07 01:34:34 INFO:GibbsSupervisedLDA:[ITER] 27,	MAE:0.09,	log_likelihood:-63294769.76
# 2019-09-07 01:39:36 INFO:GibbsSupervisedLDA:[ITER] 28,	MAE:0.09,	log_likelihood:-63138159.65
# 2019-09-07 01:44:37 INFO:GibbsSupervisedLDA:[ITER] 29,	MAE:0.09,	log_likelihood:-62985622.86
# 2019-09-07 01:49:39 INFO:GibbsSupervisedLDA:[ITER] 30,	MAE:0.09,	log_likelihood:-62840486.84
# 2019-09-07 01:54:42 INFO:GibbsSupervisedLDA:[ITER] 31,	MAE:0.09,	log_likelihood:-62699246.92
# 2019-09-07 01:59:45 INFO:GibbsSupervisedLDA:[ITER] 32,	MAE:0.09,	log_likelihood:-62557289.51
# 2019-09-07 02:04:47 INFO:GibbsSupervisedLDA:[ITER] 33,	MAE:0.09,	log_likelihood:-62418692.39
# 2019-09-07 02:09:49 INFO:GibbsSupervisedLDA:[ITER] 34,	MAE:0.09,	log_likelihood:-62286993.61
# 2019-09-07 02:14:52 INFO:GibbsSupervisedLDA:[ITER] 35,	MAE:0.09,	log_likelihood:-62157417.29
# 2019-09-07 02:19:54 INFO:GibbsSupervisedLDA:[ITER] 36,	MAE:0.09,	log_likelihood:-62027012.26
# 2019-09-07 02:24:58 INFO:GibbsSupervisedLDA:[ITER] 37,	MAE:0.09,	log_likelihood:-61901121.11
# 2019-09-07 02:30:00 INFO:GibbsSupervisedLDA:[ITER] 38,	MAE:0.09,	log_likelihood:-61776113.28
# 2019-09-07 02:35:02 INFO:GibbsSupervisedLDA:[ITER] 39,	MAE:0.09,	log_likelihood:-61656739.36
# 2019-09-07 02:40:05 INFO:GibbsSupervisedLDA:[ITER] 40,	MAE:0.09,	log_likelihood:-61539275.98
# 2019-09-07 02:45:07 INFO:GibbsSupervisedLDA:[ITER] 41,	MAE:0.09,	log_likelihood:-61425725.57
# 2019-09-07 02:50:09 INFO:GibbsSupervisedLDA:[ITER] 42,	MAE:0.09,	log_likelihood:-61313041.41
# 2019-09-07 02:55:13 INFO:GibbsSupervisedLDA:[ITER] 43,	MAE:0.09,	log_likelihood:-61203180.85
# 2019-09-07 03:00:16 INFO:GibbsSupervisedLDA:[ITER] 44,	MAE:0.09,	log_likelihood:-61100180.84
# 2019-09-07 03:05:18 INFO:GibbsSupervisedLDA:[ITER] 45,	MAE:0.09,	log_likelihood:-60995808.57
# 2019-09-07 03:10:20 INFO:GibbsSupervisedLDA:[ITER] 46,	MAE:0.09,	log_likelihood:-60891482.33
# 2019-09-07 03:15:22 INFO:GibbsSupervisedLDA:[ITER] 47,	MAE:0.09,	log_likelihood:-60795826.39
# 2019-09-07 03:20:27 INFO:GibbsSupervisedLDA:[ITER] 48,	MAE:0.09,	log_likelihood:-60699878.69
# 2019-09-07 03:25:31 INFO:GibbsSupervisedLDA:[ITER] 49,	MAE:0.09,	log_likelihood:-60604033.61
# 2019-09-07 03:30:33 INFO:GibbsSupervisedLDA:[ITER] 50,	MAE:0.09,	log_likelihood:-60512285.57
# 2019-09-07 03:35:37 INFO:GibbsSupervisedLDA:[ITER] 51,	MAE:0.09,	log_likelihood:-60419500.72
# 2019-09-07 03:40:41 INFO:GibbsSupervisedLDA:[ITER] 52,	MAE:0.09,	log_likelihood:-60333276.88
# 2019-09-07 03:45:46 INFO:GibbsSupervisedLDA:[ITER] 53,	MAE:0.09,	log_likelihood:-60246205.97
# 2019-09-07 03:50:48 INFO:GibbsSupervisedLDA:[ITER] 54,	MAE:0.09,	log_likelihood:-60165173.73
# 2019-09-07 03:55:50 INFO:GibbsSupervisedLDA:[ITER] 55,	MAE:0.09,	log_likelihood:-60084688.86
# 2019-09-07 04:00:54 INFO:GibbsSupervisedLDA:[ITER] 56,	MAE:0.09,	log_likelihood:-59998103.47
# 2019-09-07 04:05:58 INFO:GibbsSupervisedLDA:[ITER] 57,	MAE:0.09,	log_likelihood:-59927781.15
# 2019-09-07 04:11:01 INFO:GibbsSupervisedLDA:[ITER] 58,	MAE:0.09,	log_likelihood:-59848477.92
# 2019-09-07 04:16:04 INFO:GibbsSupervisedLDA:[ITER] 59,	MAE:0.09,	log_likelihood:-59771874.06
# 2019-09-07 04:21:06 INFO:GibbsSupervisedLDA:[ITER] 60,	MAE:0.09,	log_likelihood:-59703496.29
# 2019-09-07 04:26:10 INFO:GibbsSupervisedLDA:[ITER] 61,	MAE:0.09,	log_likelihood:-59638214.33
# 2019-09-07 04:31:12 INFO:GibbsSupervisedLDA:[ITER] 62,	MAE:0.09,	log_likelihood:-59572543.31
# 2019-09-07 04:36:15 INFO:GibbsSupervisedLDA:[ITER] 63,	MAE:0.09,	log_likelihood:-59507782.63
# 2019-09-07 04:41:19 INFO:GibbsSupervisedLDA:[ITER] 64,	MAE:0.09,	log_likelihood:-59450453.92
# 2019-09-07 04:46:21 INFO:GibbsSupervisedLDA:[ITER] 65,	MAE:0.09,	log_likelihood:-59389959.71
# 2019-09-07 04:51:23 INFO:GibbsSupervisedLDA:[ITER] 66,	MAE:0.09,	log_likelihood:-59332077.83
# 2019-09-07 04:56:25 INFO:GibbsSupervisedLDA:[ITER] 67,	MAE:0.09,	log_likelihood:-59277534.85
# 2019-09-07 05:01:28 INFO:GibbsSupervisedLDA:[ITER] 68,	MAE:0.09,	log_likelihood:-59225232.48
# 2019-09-07 05:06:33 INFO:GibbsSupervisedLDA:[ITER] 69,	MAE:0.09,	log_likelihood:-59176849.17
# 2019-09-07 05:11:35 INFO:GibbsSupervisedLDA:[ITER] 70,	MAE:0.09,	log_likelihood:-59125861.88
# 2019-09-07 05:16:38 INFO:GibbsSupervisedLDA:[ITER] 71,	MAE:0.09,	log_likelihood:-59078911.51
# 2019-09-07 05:21:42 INFO:GibbsSupervisedLDA:[ITER] 72,	MAE:0.09,	log_likelihood:-59030939.30
# 2019-09-07 05:26:45 INFO:GibbsSupervisedLDA:[ITER] 73,	MAE:0.09,	log_likelihood:-58981126.66
# 2019-09-07 05:31:49 INFO:GibbsSupervisedLDA:[ITER] 74,	MAE:0.09,	log_likelihood:-58935732.48
# 2019-09-07 05:36:51 INFO:GibbsSupervisedLDA:[ITER] 75,	MAE:0.09,	log_likelihood:-58891887.65
# 2019-09-07 05:41:53 INFO:GibbsSupervisedLDA:[ITER] 76,	MAE:0.09,	log_likelihood:-58852439.97
# 2019-09-07 05:46:56 INFO:GibbsSupervisedLDA:[ITER] 77,	MAE:0.09,	log_likelihood:-58810002.15
# 2019-09-07 05:52:00 INFO:GibbsSupervisedLDA:[ITER] 78,	MAE:0.09,	log_likelihood:-58767375.18
# 2019-09-07 05:57:03 INFO:GibbsSupervisedLDA:[ITER] 79,	MAE:0.09,	log_likelihood:-58724754.30
# 2019-09-07 06:02:07 INFO:GibbsSupervisedLDA:[ITER] 80,	MAE:0.09,	log_likelihood:-58681835.81
# 2019-09-07 06:07:09 INFO:GibbsSupervisedLDA:[ITER] 81,	MAE:0.09,	log_likelihood:-58642481.68
# 2019-09-07 06:12:14 INFO:GibbsSupervisedLDA:[ITER] 82,	MAE:0.09,	log_likelihood:-58595518.95
# 2019-09-07 06:17:16 INFO:GibbsSupervisedLDA:[ITER] 83,	MAE:0.09,	log_likelihood:-58559082.72
# 2019-09-07 06:22:21 INFO:GibbsSupervisedLDA:[ITER] 84,	MAE:0.09,	log_likelihood:-58517722.09
# 2019-09-07 06:27:24 INFO:GibbsSupervisedLDA:[ITER] 85,	MAE:0.09,	log_likelihood:-58482056.55
# 2019-09-07 06:32:28 INFO:GibbsSupervisedLDA:[ITER] 86,	MAE:0.09,	log_likelihood:-58444662.32
# 2019-09-07 06:37:32 INFO:GibbsSupervisedLDA:[ITER] 87,	MAE:0.09,	log_likelihood:-58408561.97
# 2019-09-07 06:42:35 INFO:GibbsSupervisedLDA:[ITER] 88,	MAE:0.09,	log_likelihood:-58370521.48
# 2019-09-07 06:47:39 INFO:GibbsSupervisedLDA:[ITER] 89,	MAE:0.09,	log_likelihood:-58331368.53
# 2019-09-07 06:52:42 INFO:GibbsSupervisedLDA:[ITER] 90,	MAE:0.08,	log_likelihood:-58296911.83
# 2019-09-07 06:57:45 INFO:GibbsSupervisedLDA:[ITER] 91,	MAE:0.08,	log_likelihood:-58259269.04
# 2019-09-07 07:02:50 INFO:GibbsSupervisedLDA:[ITER] 92,	MAE:0.08,	log_likelihood:-58223729.73
# 2019-09-07 07:07:51 INFO:GibbsSupervisedLDA:[ITER] 93,	MAE:0.08,	log_likelihood:-58192023.24
# 2019-09-07 07:12:55 INFO:GibbsSupervisedLDA:[ITER] 94,	MAE:0.08,	log_likelihood:-58164825.26
# 2019-09-07 07:17:58 INFO:GibbsSupervisedLDA:[ITER] 95,	MAE:0.08,	log_likelihood:-58134696.17
# 2019-09-07 07:23:02 INFO:GibbsSupervisedLDA:[ITER] 96,	MAE:0.08,	log_likelihood:-58106230.88
# 2019-09-07 07:28:06 INFO:GibbsSupervisedLDA:[ITER] 97,	MAE:0.08,	log_likelihood:-58080326.12
# 2019-09-07 07:33:09 INFO:GibbsSupervisedLDA:[ITER] 98,	MAE:0.08,	log_likelihood:-58053697.79
# 2019-09-07 07:38:12 INFO:GibbsSupervisedLDA:[ITER] 99,	MAE:0.08,	log_likelihood:-58026709.36

# %%
# Printing the result of sLDA
voca = []
for i in range(n_voca):
    voca.append(dictionary[i])

for ti in model.eta.argsort():
    top_words = get_top_words(model.TW, voca, ti, n_words=15)
    print('Eta', model.eta[ti] ,'Topic', ti ,':\t', ','.join(top_words))
# Out:
# Eta -7.96827685638431 Topic 1 :	 start,woman,best,cop,way,real,school,donald,free,change,racist,things,remember,make,listen
# Eta -5.648898978532803 Topic 5 :	 woman,start,cop,hear,change,way,better,men,real,follow,best,free,music,join,read
# Eta -3.367248370734816 Topic 6 :	 nowplaying,god,music,best,listen,shit,fuck,start,check,real,happy,staywoke,lol,beat,talk
# Eta -3.3213037794588014 Topic 13 :	 cop,russia,donald,officer,report,protest,arrest,election,charge,plan,war,gun,death,law,judge
# Eta -2.1533976364066874 Topic 16 :	 racism,fight,history,health,americans,care,enlist,change,way,race,ppl,stand,party,racist,freedom
# Eta -1.1624227265095761 Topic 14 :	 music,follow,free,check,twitter,beat,nowplaying,issue,listen,share,artists,track,radio,hiphop,hit
# Eta -1.0124758449543325 Topic 3 :	 cop,case,king,justice,campaign,money,pay,ask,hand,murder,run,folks,mean,meet,officer
# Eta 1.1938249806105234 Topic 8 :	 fakenews,muslim,gun,isis,islam,muslims,claim,law,islamic,anti,terror,ban,illegal,control,weinstein
# Eta 1.197965450424175 Topic 18 :	 isis,target,north,iran,korea,court,order,account,syria,post,deal,nuclear,federal,report,war
# Eta 1.2202776630667649 Topic 7 :	 antifa,nfl,korea,lol,viral,north,liberal,expose,anthem,liberals,tweet,supporters,anti,stand,traitor
# Eta 1.2526547566329662 Topic 19 :	 old,cop,woman,kid,school,children,girl,men,murder,dog,arrest,sex,die,fuck,parent
# Eta 1.258164409486514 Topic 15 :	 sport,music,nowplaying,christmas,night,game,best,star,book,beat,listen,happy,check,feat,week
# Eta 1.2641791981468482 Topic 12 :	 god,country,americans,hillaryclinton,democrats,party,foxnews,mar,believe,trumptrain,way,poll,demdebate,lose,racist
# Eta 1.6470084930201694 Topic 4 :	 fbi,russia,comey,mueller,email,lynch,doj,fake,investigation,dnc,congress,leak,expose,report,hack
# Eta 1.9952209618281675 Topic 0 :	 tax,pay,hedgebz,islamkills,money,refugees,job,million,cut,fund,archive,obamacare,plan,brussels,spend
# Eta 2.0900990471647236 Topic 9 :	 cruz,ccot,gopdebate,plan,ted,god,click,fight,debate,soundcloud,tedcruz,stopthegop,cruzcrew,donald,parenthood
# Eta 3.535746377265476 Topic 2 :	 enlist,army,patriot,stand,join,usfa,freedom,fight,flag,patriots,antifa,speech,free,gun,group
# Eta 3.584754963912028 Topic 17 :	 election,campaign,democrats,run,senate,poll,joe,moore,post,john,donald,judge,tweet,sheriff,dems
# Eta 3.6283200528409827 Topic 10 :	 home,local,old,die,dead,feel,god,make,woman,texas,little,dog,christmas,kid,away
# Eta 6.009107659577894 Topic 11 :	 nfl,country,job,donald,national,gun,liberals,fake,change,korea,lose,liberal,claim,isis,anthem

# %%
# Generate Helpout Doc for testing the model
test_dictionary = corpora.Dictionary(test_docs)
test_dictionary.filter_n_most_frequent(20)
test_dictionary.filter_extremes(no_below=2, keep_n=30000)

test_doc_term_matrix = [test_dictionary.doc2bow(doc) for doc in test_docs]

# %%
# Generating testing corpus
test_corpus = []
for i in range(len(test_doc_term_matrix)):
    corp = []
    for j in range(len(test_doc_term_matrix[i])):
        for x in range(test_doc_term_matrix[i][j][1]):
            
            corp.append(test_doc_term_matrix[i][j][0])
    test_corpus.append(corp)

# %%
# Predicting troll category for testing dataset using generated sLDA model
max_iter = 100
h_doc_topic_sum = model.sample_heldout_doc(max_iter, test_corpus)

# %%
# Normalise topic assignments
normalised_topic_assi = h_doc_topic_sum
length = len(h_doc_topic_sum)
for i in range(length):
    sum = 0
    l = len(h_doc_topic_sum[i])
    for j in range(l):
        sum += h_doc_topic_sum[i][j]
    for j in range(l):
        normalised_topic_assi[i][j] = h_doc_topic_sum[i][j] / sum

# %%
# Calculating predicted troll category for each tweet
predicted_value = normalised_topic_assi .dot (model.eta)

# %%
# Change continuous predicted label to either -1 or +1
for i in range(len(predicted_value)):
    if predicted_value[i] > 0:
        predicted_value[i] = 1
    elif predicted_value[i] < 0:
        predicted_value[i] = -1

# %%
# Calculating the mae
mae = np.mean(np.abs(test_ratings - predicted_value))
mae
# Out:
# 0.9832435039741627

# %% [markdown]
# ### Sentiment Analysis
# Interesting topic

# %%
# Normalise DT
normalised_DT = model.DT
length = len(model.DT)
for i in range(length):
    sum = 0
    l = len(model.DT[i])
    for j in range(l):
        sum += model.DT[i][j]
    for j in range(l):
        normalised_DT[i][j] = model.DT[i][j] / sum

# %%
# Choose the interesting topic manually accrording to the result of sLDA
interested_topic = 11
threshold = 0.55
# Genarate corpus for sentiment prediction
corpus = []
for i in range(len(normalised_DT)):
    if normalised_DT[i][interested_topic] >= threshold:
        corpus.append(df_tweets.loc[i, 'content'])

# %%
corpus
# Out:
# ['"It took Hillary abt 5 minutes to blame NRA for madman\'s rampage, but 5 days to sorta-kinda blame Harvey Weinstein 4 his sexually assaults." https://t.co/uzZ5obFGiO',
#  "Liberal's are the most hate filled, racist, hypocritical, bigoted, irrational &amp; mentally unstable creatures on earth. A danger to the world. https://t.co/qpzuVTlhAL",
#  'Clay Travis stuns CNN host when he says he believes in two things: the First Amendment and Boobs.   Priceless. He wins the day,😂 https://t.co/ELXA16MCSi',
#  '"When President Trump touched those ancient stones, he touched our hearts forever." ~ @netanyahu   Tell me again how Trump is Anti Semitic https://t.co/LwtTRUI75i',
#  'RT ChasD3: Strange how no one blamed Bernie Sanders for the shooter of Steve Scalise. But left blames Trump for the killing of the woman by…',
#  'I think one girl is all you need, @realDonaldTrump. Drudge: Romney Leads Picks for Secretary of State... Nikki Haley for UN ambassador...',
#  '��Berkeley Students SUPPORT Man Waving ISIS Flag - Then ATTACK Same Guy When He Waves Israeli Flag https://t.co/FHa6xXrTI0',
#  "Wiki leaks doesn't lie,they LEAK.Obamas FINALLY getting exposed for his dirty dealings!Obamas deflecting by accusing @POTUS as crazy.  #MAGA https://t.co/oKeiaWzemH",
#  'Had the honor of hearing @KrisParonto speak at a luncheon today.Never Forget those lost n #benghazi bc sick hillary https://t.co/Cuwe3XeaiR',
#  'RT BarbMuenchen: Spreading the Hate! #Democrat hate is destroying 🇺🇸STOP it! 😡#FakeNews giving their hateful opini… https://t.co/B0TTlKdjVD',
#  'Texas officer on leave after video shows him pushing teen, pulling gun after pool party  #news',
#  "Imagine a Hollywood celebrity tweeting their wish for Obama's death.   That would be CNN's lead story in seconds. https://t.co/hpYY90fud6",
#  'President-elect Trump and VP-elect Pence have spoken to many foreign leaders over the past week. See the list here: https://t.co/VgCyHIPtma',
#  'I had armed SROs when I was in school, as did my oldest daughter.   Of course, my school also had a range and a rifle team... https://t.co/uW3n0gKaa7',
#  'BLACK LIVES MATTER HATE INTERRUPTS #DNC MOMENT OF SILENCE FOR MURDERED POLICE  https://t.co/FgG7ALtpSj #crookedhillary #Clinton #Mexico',
#  "Charlotte Church was asked to sing at Trump inauguration, but she refused The moment when your stupidity doesn't let you to make a career https://t.co/zkIs8pq2dV",
#  'UCLA students in protest of Donald Trumps election Will they start looting and fighting? Or is this another category? https://t.co/gsUfJNtxaF',
#  'Liberal indoctrination and the mainstream media\'s relentless pursuit of anti-gun narrative has manipulated high school kids to "walk out for gun control." Should\'ve spent that time teaching respect and morals.',
#  'Family of Black Boy Found Burned Alive in Trash Can, UNLOADS on Black Lives Matter ⋆ Freedom Daily https://t.co/DBCKYf4HlF',
#  '#top RT President1Trump: Kid rock for senate gives hero a surprise visit and a new home #KidRockForSenate #Heroes https://t.co/T0XVYXRknK',
#  '#topl RT Conservatexian: News post: "AMAZING! 10-Year-Old Entrepreneur Asks President Trump if He Can Mow the White House Lawn . . . And PO…',
#  'BLACK LIVES MATTER HATE INTERRUPTS #DNC MOMENT OF SILENCE FOR MURDERED POLICE  https://t.co/FgG7ALtpSj #crookedhillary #Clinton #Mexico',
#  '#MSNBC at the bottom of journalism so funny Rachel Maddow Claims She Has Trump’s Tax Returns" ��  waste of time',
#  'Actually read yesterday someone say "Why hate them (Jewish people) for being successful". It\'s like WHOA! Wait up, who said "hate"?',
#  'SAD END, RIP, ANOTHER FALLEN LAW OFFICER, GOD BLESS HIM & HIS LOVED ONES! https://t.co/dzjmH3wkpJ']

# %% [markdown]
# Building Sentiment Analysis model

# %%
import nltk
import random
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from nltk.classify import ClassifierI
from statistics import mode
from nltk.tokenize import word_tokenize
import re
import os

corp = pd.read_csv("tn.csv",encoding ="ISO-8859-1",header=None)
corpus_all  =  corp.drop([1, 2, 3, 4], axis=1)
n = len(corpus_all)

corpus_pos = list()
corpus_neg = list()
for i in range(n):
    if corpus_all.loc[i, 0] == 0:
        corpus_neg.append(corpus_all.loc[i, 5])
    elif corpus_all.loc[i, 0] == 4:
        corpus_pos.append(corpus_all.loc[i, 5])

files_pos = corpus_pos[750000:]
files_neg = corpus_neg[750000:]

all_words = []
documents = []

from nltk.corpus import stopwords
import re

stop_words = list(set(stopwords.words('english')))

#  j is adject, r is adverb, and v is verb
#allowed_word_types = ["J","R","V"]
allowed_word_types = ["J"]

for p in  files_pos:
    
    # create a list of tuples where the first element of each tuple is a review
    # the second element is the label
    documents.append( (p, "pos") )
    
    # remove punctuations
    cleaned = re.sub(r'[^(a-zA-Z)\s]','', p)
    
    # tokenize 
    tokenized = word_tokenize(cleaned)
    
    # remove stopwords 
    stopped = [w for w in tokenized if not w in stop_words]
    
    # parts of speech tagging for each word 
    pos = nltk.pos_tag(stopped)
    
    # make a list of  all adjectives identified by the allowed word types list above
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())

    
for p in files_neg:
    # create a list of tuples where the first element of each tuple is a review
    # the second element is the label
    documents.append( (p, "neg") )
    
    # remove punctuations
    cleaned = re.sub(r'[^(a-zA-Z)\s]','', p)
    
    # tokenize 
    tokenized = word_tokenize(cleaned)
    
    # remove stopwords 
    stopped = [w for w in tokenized if not w in stop_words]
    
    # parts of speech tagging for each word 
    neg = nltk.pos_tag(stopped)
    
    # make a list of  all adjectives identified by the allowed word types list above
    for w in neg:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())

# %%
# creating a frequency distribution of each adjectives. 
BOW = nltk.FreqDist(all_words)


# listing the 5000 most frequent words
word_features = list(BOW.keys())[:5000]
word_features[0], word_features[-1]


# function to create a dictionary of features for each review in the list document.
# The keys are the words in word_features 
# The values of each key are either true or false for wether that feature appears in the review or not
def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

# Creating features for each review
featuresets = [(find_features(rev), category) for (rev, category) in documents]

# Shuffling the documents 
random.shuffle(featuresets)


training_set = featuresets[:80000]
testing_set = featuresets[80000:]
print( 'training_set :', len(training_set), '\ntesting_set :', len(testing_set))


classifier = nltk.NaiveBayesClassifier.train(training_set)

print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, testing_set))*100)

classifier.show_most_informative_features(15)


# Printing the most important features 
mif = classifier.most_informative_features()

mif = [a for a,b in mif]
print(mif)


# getting predictions for the testing set by looping over each reviews featureset tuple
# The first elemnt of the tuple is the feature set and the second element is the label 
ground_truth = [r[1] for r in testing_set]

preds = [classifier.classify(r[0]) for r in testing_set]


from sklearn.metrics import f1_score
f1_score(ground_truth, preds, labels = ['neg', 'pos'], average = 'micro')
# Out:
# training_set : 80000
# testing_set : 20000
# Classifier accuracy percent: 69.425
# Most Informative Features
#                      vip = True              pos : neg    =     76.1 : 1.0
#                      sad = True              neg : pos    =     21.8 : 1.0
#                nominated = True              pos : neg    =     19.7 : 1.0
#                    humid = True              neg : pos    =     19.0 : 1.0
#                      fri = True              neg : pos    =     17.7 : 1.0
#                depressed = True              neg : pos    =     14.3 : 1.0
#                  stomach = True              neg : pos    =     14.2 : 1.0
#            ashleytisdale = True              pos : neg    =     13.4 : 1.0
#                    metro = True              neg : pos    =     13.0 : 1.0
#                     ouch = True              neg : pos    =     12.7 : 1.0
#              musicmonday = True              pos : neg    =     12.6 : 1.0
#                 terrible = True              neg : pos    =     11.4 : 1.0
#                    upset = True              neg : pos    =     11.4 : 1.0
#                inspiring = True              pos : neg    =     11.0 : 1.0
#                    awful = True              neg : pos    =     10.4 : 1.0
# ['vip', 'sad', 'nominated', 'humid', 'fri', 'depressed', 'stomach', 'ashleytisdale', 'metro', 'ouch', 'musicmonday', 'terrible', 'upset', 'inspiring', 'awful', 'vet', 'welcome', 'thnx', 'productive', 'hilarious', 'props', 'feedback', 'horrible', 'ugh', 'sick', 'poor', 'frustrated', 'teen', 'perez', 'girlie', 'voted', 'add', 'hate', 'lobster', 'funniest', 'exclusive', 'jb', 'amandapalmer', 'broken', 'sore', 'twilight', 'ughh', 'proud', 'crashing', 'worried', 'stephenfry', 'dreadful', 'horrid', 'loveee', 'dr', 'garlic', 'crash', 'retweet', 'crappy', 'failed', 'smile', 'sigh', 'thank', 'mcflymusic', 'worst', 'cranky', 'dessert', 'sunburn', 'curse', 'disappointed', 'delightful', 'prof', 'flower', 'featured', 'whew', 'stuck', 'bloody', 'fail', 'miss', 'sudden', 'previous', 'punched', 'listenin', 'cutie', 'nasty', 'ftw', 'hehe', 'thx', 'angry', 'appreciate', 'stupid', 'dead', 'sucky', 'sunburned', 'sensitive', 'nose', 'grateful', 'younger', 'handsome', 'insight', 'practical', 'accomplish', 'lime', 'mature', 'fairy']
# 0.69425

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB,BernoulliNB
from sklearn.linear_model import LogisticRegression,SGDClassifier
from sklearn.metrics import f1_score, accuracy_score
from nltk.classify import ClassifierI


print("Original Naive Bayes Algo accuracy percent:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)

MNB_clf = SklearnClassifier(MultinomialNB())
MNB_clf.train(training_set)
print("MNB_classifier accuracy percent:", (nltk.classify.accuracy(MNB_clf, testing_set))*100)

BNB_clf = SklearnClassifier(BernoulliNB())
BNB_clf.train(training_set)
print("BernoulliNB_classifier accuracy percent:", (nltk.classify.accuracy(BNB_clf, testing_set))*100)

LogReg_clf = SklearnClassifier(LogisticRegression())
LogReg_clf.train(training_set)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogReg_clf, testing_set))*100)

SGD_clf = SklearnClassifier(SGDClassifier())
SGD_clf.train(training_set)
print("SGDClassifier_classifier accuracy percent:", (nltk.classify.accuracy(SGD_clf, testing_set))*100)



classifiers_dict = {'ONB': classifier,
                    'MNB': MNB_clf,
                    'BNB': BNB_clf, 
                    'LogReg': LogReg_clf, 
                    'SGD': SGD_clf}


ground_truth = [r[1] for r in testing_set]
predictions = {}
f1_scores = {}
for clf, listy in classifiers_dict.items(): 
    # getting predictions for the testing set by looping over each reviews featureset tuple
    # The first elemnt of the tuple is the feature set and the second element is the label 
    predictions[clf] = [listy.classify(r[0]) for r in testing_set]
    f1_scores[clf] = f1_score(ground_truth, predictions[clf], labels = ['neg', 'pos'], average = 'micro')
    print(f'f1_score {clf}: {f1_scores[clf]}')
    



# Defininig the ensemble model class 

class EnsembleClassifier(ClassifierI):
    
    def __init__(self, *classifiers):
        self._classifiers = classifiers
    
    # returns the classification based on majority of votes
    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)
    # a simple measurement the degree of confidence in the classification 
    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)

        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        return conf
# Out:
# Original Naive Bayes Algo accuracy percent: 69.425
# Most Informative Features
#                      vip = True              pos : neg    =     76.1 : 1.0
#                      sad = True              neg : pos    =     21.8 : 1.0
#                nominated = True              pos : neg    =     19.7 : 1.0
#                    humid = True              neg : pos    =     19.0 : 1.0
#                      fri = True              neg : pos    =     17.7 : 1.0
#                depressed = True              neg : pos    =     14.3 : 1.0
#                  stomach = True              neg : pos    =     14.2 : 1.0
#            ashleytisdale = True              pos : neg    =     13.4 : 1.0
#                    metro = True              neg : pos    =     13.0 : 1.0
#                     ouch = True              neg : pos    =     12.7 : 1.0
#              musicmonday = True              pos : neg    =     12.6 : 1.0
#                 terrible = True              neg : pos    =     11.4 : 1.0
#                    upset = True              neg : pos    =     11.4 : 1.0
#                inspiring = True              pos : neg    =     11.0 : 1.0
#                    awful = True              neg : pos    =     10.4 : 1.0
# MNB_classifier accuracy percent: 69.49
# BernoulliNB_classifier accuracy percent: 69.475
# D:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression_classifier accuracy percent: 69.74000000000001
# D:\Anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# SGDClassifier_classifier accuracy percent: 69.105
# f1_score ONB: 0.69425
# f1_score MNB: 0.6949
# f1_score BNB: 0.69475
# f1_score LogReg: 0.6974
# f1_score SGD: 0.69105

# %%
# Initializing the ensemble classifier 
ensemble_clf = EnsembleClassifier(classifier,MNB_clf,BNB_clf,LogReg_clf,SGD_clf)

# List of only feature dictionary from the featureset list of tuples 
feature_list = [f[0] for f in testing_set]

# Looping over each to classify each review
ensemble_preds = [ensemble_clf.classify(features) for features in feature_list]

f1_score(ground_truth, ensemble_preds, average = 'micro')

# Function to do classification a given review and return the label a
# and the amount of confidence in the classifications
def sentiment(text):
    feats = find_features(text)
    return ensemble_clf.classify(feats), ensemble_clf.confidence(feats)

# %%
for i in range(len(corpus)):
    print(corpus[i])
    print(sentiment(corpus[i]))
# Out:
# "It took Hillary abt 5 minutes to blame NRA for madman's rampage, but 5 days to sorta-kinda blame Harvey Weinstein 4 his sexually assaults." https://t.co/uzZ5obFGiO
# ('neg', 1.0)
# Liberal's are the most hate filled, racist, hypocritical, bigoted, irrational &amp; mentally unstable creatures on earth. A danger to the world. https://t.co/qpzuVTlhAL
# ('pos', 1.0)
# Clay Travis stuns CNN host when he says he believes in two things: the First Amendment and Boobs.   Priceless. He wins the day,😂 https://t.co/ELXA16MCSi
# ('neg', 1.0)
# "When President Trump touched those ancient stones, he touched our hearts forever." ~ @netanyahu   Tell me again how Trump is Anti Semitic https://t.co/LwtTRUI75i
# ('neg', 0.6)
# RT ChasD3: Strange how no one blamed Bernie Sanders for the shooter of Steve Scalise. But left blames Trump for the killing of the woman by…
# ('pos', 1.0)
# I think one girl is all you need, @realDonaldTrump. Drudge: Romney Leads Picks for Secretary of State... Nikki Haley for UN ambassador...
# #MSNBC at the bottom of journalism so funny Rachel Maddow Claims She Has Trump’s Tax Returns" ��  waste of time
# ('neg', 0.8)
# Actually read yesterday someone say "Why hate them (Jewish people) for being successful". It's like WHOA! Wait up, who said "hate"?
# ('pos', 1.0)
# SAD END, RIP, ANOTHER FALLEN LAW OFFICER, GOD BLESS HIM & HIS LOVED ONES! https://t.co/dzjmH3wkpJ
# ('neg', 1.0)

# %% [markdown]
# # Restricted time range

# %%
df_tweets_2017 = df_tweets[((df_tweets['publish_date'] >= '2017-01-01') & (df_tweets['publish_date'] <= '2017-12-31'))]
test_df_tweets_2017 = test_df_tweets[((test_df_tweets['publish_date'] >= '2017-01-01') & (test_df_tweets['publish_date'] <= '2017-12-31'))]

df_tweets_2016 = df_tweets[((df_tweets['publish_date'] >= '2016-01-01') & (df_tweets['publish_date'] <= '2016-12-31'))]
test_df_tweets_2016 = test_df_tweets[((test_df_tweets['publish_date'] >= '2016-01-01') & (test_df_tweets['publish_date'] <= '2016-12-31'))]

df_tweets_2015 = df_tweets[((df_tweets['publish_date'] >= '2015-01-01') & (df_tweets['publish_date'] <= '2015-12-31'))]
test_df_tweets_2015 = test_df_tweets[((test_df_tweets['publish_date'] >= '2015-01-01') & (test_df_tweets['publish_date'] <= '2015-12-31'))]

df_tweets_2017 = df_tweets_2017.reset_index(drop=True)
test_df_tweets_2017 = test_df_tweets_2017.reset_index(drop=True)

df_tweets_2016 = df_tweets_2016.reset_index(drop=True)
test_df_tweets_2016 = test_df_tweets_2016.reset_index(drop=True)

df_tweets_2015 = df_tweets_2015.reset_index(drop=True)
test_df_tweets_2015 = test_df_tweets_2015.reset_index(drop=True)

ratings_2017 =  df_tweets_2017.drop(['content', 'publish_date', 'index'], axis=1)
test_ratings_2017 =  test_df_tweets_2017.drop(['content', 'publish_date', 'index'], axis=1)

ratings_2016 =  df_tweets_2016.drop(['content', 'publish_date', 'index'], axis=1)
test_ratings_2016 =  test_df_tweets_2016.drop(['content', 'publish_date', 'index'], axis=1)

ratings_2015 =  df_tweets_2015.drop(['content', 'publish_date', 'index'], axis=1)
test_ratings_2015 =  test_df_tweets_2015.drop(['content', 'publish_date', 'index'], axis=1)

for i in range(len(df_tweets_2017)):
    if ratings_2017.loc[i, 'account_category'] == 'LeftTroll':
        ratings_2017.loc[i, 'account_category'] = -1
    elif ratings_2017.loc[i, 'account_category'] == 'RightTroll':
        ratings_2017.loc[i, 'account_category'] = 1
for i in range(len(test_df_tweets_2017)):
    if test_ratings_2017.loc[i, 'account_category'] == 'LeftTroll':
        test_ratings_2017.loc[i, 'account_category'] = -1
    elif test_ratings_2017.loc[i, 'account_category'] == 'RightTroll':
        test_ratings_2017.loc[i, 'account_category'] = 1
        
for i in range(len(df_tweets_2016)):
    if ratings_2016.loc[i, 'account_category'] == 'LeftTroll':
        ratings_2016.loc[i, 'account_category'] = -1
    elif ratings_2016.loc[i, 'account_category'] == 'RightTroll':
        ratings_2016.loc[i, 'account_category'] = 1
for i in range(len(test_df_tweets_2016)):
    if test_ratings_2016.loc[i, 'account_category'] == 'LeftTroll':
        test_ratings_2016.loc[i, 'account_category'] = -1
    elif test_ratings_2016.loc[i, 'account_category'] == 'RightTroll':
        test_ratings_2016.loc[i, 'account_category'] = 1
        
for i in range(len(df_tweets_2015)):
    if ratings_2015.loc[i, 'account_category'] == 'LeftTroll':
        ratings_2015.loc[i, 'account_category'] = -1
    elif ratings_2015.loc[i, 'account_category'] == 'RightTroll':
        ratings_2015.loc[i, 'account_category'] = 1
for i in range(len(test_df_tweets_2015)):
    if test_ratings_2015.loc[i, 'account_category'] == 'LeftTroll':
        test_ratings_2015.loc[i, 'account_category'] = -1
    elif test_ratings_2015.loc[i, 'account_category'] == 'RightTroll':
        test_ratings_2015.loc[i, 'account_category'] = 1
        

ratings_2017 = ratings_2017.values.flatten()
test_ratings_2017 = test_ratings_2017.values.flatten()

ratings_2016 = ratings_2016.values.flatten()
test_ratings_2016 = test_ratings_2016.values.flatten()

ratings_2015 = ratings_2015.values.flatten()
test_ratings_2015 = test_ratings_2015.values.flatten()

# %%
import string
import nltk
from nltk.tokenize import WordPunctTokenizer

from nltk.stem import WordNetLemmatizer, SnowballStemmer
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS

import gensim
from gensim import corpora


punctuation = set(string.punctuation)

stemmer = SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

def preprocessor(text):
    tokens = WordPunctTokenizer().tokenize(text.lower())
    stems = []
    for token in tokens:
        if token.isalpha() and token not in gensim.parsing.preprocessing.STOPWORDS and token not in punctuation and len(token) >= 3 and len(token) <= 14:
            stems.append(lemmatizer.lemmatize(token, pos='v'))
   
    return stems

docs_2017 = df_tweets_2017['content'].map(preprocessor)
test_docs_2017 = test_df_tweets_2017['content'].map(preprocessor)

docs_2016 = df_tweets_2016['content'].map(preprocessor)
test_docs_2016 = test_df_tweets_2016['content'].map(preprocessor)

docs_2015 = df_tweets_2015['content'].map(preprocessor)
test_docs_2015 = test_df_tweets_2015['content'].map(preprocessor)

# %%
# Creating dictionary for corpus
dictionary_2017 = corpora.Dictionary(docs_2017)
test_dictionary_2017 = corpora.Dictionary(test_docs_2017)

dictionary_2016 = corpora.Dictionary(docs_2016)
test_dictionary_2016 = corpora.Dictionary(test_docs_2016)

dictionary_2015 = corpora.Dictionary(docs_2015)
test_dictionary_2015 = corpora.Dictionary(test_docs_2015)


dictionary_2017.filter_n_most_frequent(20)
dictionary_2017.filter_extremes(no_below=3, keep_n=30000)
test_dictionary_2017.filter_n_most_frequent(5)
test_dictionary_2017.filter_extremes(no_below=2, keep_n=30000)

dictionary_2016.filter_n_most_frequent(20)
dictionary_2016.filter_extremes(no_below=3, keep_n=30000)
test_dictionary_2016.filter_n_most_frequent(5)
test_dictionary_2016.filter_extremes(no_below=2, keep_n=30000)

dictionary_2015.filter_n_most_frequent(20)
dictionary_2015.filter_extremes(no_below=3, keep_n=30000)
test_dictionary_2015.filter_n_most_frequent(5)
test_dictionary_2015.filter_extremes(no_below=2, keep_n=30000)

# Generate Document-Term matrix
doc_term_matrix_2017 = [dictionary_2017.doc2bow(doc) for doc in docs_2017]
test_doc_term_matrix_2017 = [test_dictionary_2017.doc2bow(doc) for doc in test_docs_2017]

doc_term_matrix_2016 = [dictionary_2016.doc2bow(doc) for doc in docs_2016]
test_doc_term_matrix_2016 = [test_dictionary_2016.doc2bow(doc) for doc in test_docs_2016]

doc_term_matrix_2015 = [dictionary_2015.doc2bow(doc) for doc in docs_2015]
test_doc_term_matrix_2015 = [test_dictionary_2015.doc2bow(doc) for doc in test_docs_2015]

# %%
n_doc_2017 = len(doc_term_matrix_2017)
n_voca_2017 = len(dictionary_2017)
test_n_doc_2017 = len(test_doc_term_matrix_2017)

n_doc_2016 = len(doc_term_matrix_2016)
n_voca_2016 = len(dictionary_2016)
test_n_doc_2016 = len(test_doc_term_matrix_2016)

n_doc_2015 = len(doc_term_matrix_2015)
n_voca_2015 = len(dictionary_2015)
test_n_doc_2015 = len(test_doc_term_matrix_2015)

n_topic = 20
r_var = 0.01


corpus_2017 = []
test_corpus_2017 = []
test_corpus_2016 = []
test_corpus_2015 = []
corpus_2016 = []
corpus_2015 = []
for i in range(n_doc_2017):
    corp = []
    for j in range(len(doc_term_matrix_2017[i])):
        for x in range(doc_term_matrix_2017[i][j][1]):
            
            corp.append(doc_term_matrix_2017[i][j][0])
    corpus_2017.append(corp)   
for i in range(test_n_doc_2017):
    corp = []
    for j in range(len(test_doc_term_matrix_2017[i])):
        for x in range(test_doc_term_matrix_2017[i][j][1]):
            
            corp.append(test_doc_term_matrix_2017[i][j][0])
    test_corpus_2017.append(corp) 
    
for i in range(n_doc_2016):
    corp = []
    for j in range(len(doc_term_matrix_2016[i])):
        for x in range(doc_term_matrix_2016[i][j][1]):
            
            corp.append(doc_term_matrix_2016[i][j][0])
    corpus_2016.append(corp)   
for i in range(test_n_doc_2016):
    corp = []
    for j in range(len(test_doc_term_matrix_2016[i])):
        for x in range(test_doc_term_matrix_2016[i][j][1]):
            
            corp.append(test_doc_term_matrix_2016[i][j][0])
    test_corpus_2016.append(corp) 
    
for i in range(n_doc_2015):
    corp = []
    for j in range(len(doc_term_matrix_2015[i])):
        for x in range(doc_term_matrix_2015[i][j][1]):
            
            corp.append(doc_term_matrix_2015[i][j][0])
    corpus_2015.append(corp)   
for i in range(test_n_doc_2015):
    corp = []
    for j in range(len(test_doc_term_matrix_2015[i])):
        for x in range(test_doc_term_matrix_2015[i][j][1]):
            
            corp.append(test_doc_term_matrix_2015[i][j][0])
    test_corpus_2015.append(corp)

# %%
model_2017= GibbsSupervisedLDA(n_doc_2017, n_voca_2017, n_topic, sigma=r_var)
model_2017.fit(corpus_2017, ratings_2017)

voca = []
for i in range(n_voca_2017):
    voca.append(dictionary_2017[i])

for ti in model_2017.eta.argsort():
    top_words = get_top_words(model_2017.TW, voca, ti, n_words=15)
    print('Eta', model_2017.eta[ti] ,'Topic', ti ,':\t', ','.join(top_words))
# Out:
# 2019-07-20 16:45:46 INFO:GibbsSupervisedLDA:[ITER] 0,	MAE:0.10,	log_likelihood:-34805794.69
# 2019-07-20 16:50:03 INFO:GibbsSupervisedLDA:[ITER] 1,	MAE:0.10,	log_likelihood:-34211993.92
# 2019-07-20 16:54:19 INFO:GibbsSupervisedLDA:[ITER] 2,	MAE:0.10,	log_likelihood:-33869111.33
# 2019-07-20 16:58:34 INFO:GibbsSupervisedLDA:[ITER] 3,	MAE:0.10,	log_likelihood:-33612435.12
# 2019-07-20 17:02:53 INFO:GibbsSupervisedLDA:[ITER] 4,	MAE:0.10,	log_likelihood:-33405070.04
# 2019-07-20 17:07:09 INFO:GibbsSupervisedLDA:[ITER] 5,	MAE:0.10,	log_likelihood:-33229155.92
# 2019-07-20 17:11:24 INFO:GibbsSupervisedLDA:[ITER] 6,	MAE:0.10,	log_likelihood:-33070835.78
# 2019-07-20 17:15:40 INFO:GibbsSupervisedLDA:[ITER] 7,	MAE:0.10,	log_likelihood:-32926449.58
# 2019-07-20 17:19:55 INFO:GibbsSupervisedLDA:[ITER] 8,	MAE:0.10,	log_likelihood:-32795333.79
# 2019-07-20 17:24:11 INFO:GibbsSupervisedLDA:[ITER] 9,	MAE:0.10,	log_likelihood:-32668437.13
# 2019-07-20 17:28:29 INFO:GibbsSupervisedLDA:[ITER] 10,	MAE:0.10,	log_likelihood:-32546140.51
# 2019-07-20 17:32:52 INFO:GibbsSupervisedLDA:[ITER] 11,	MAE:0.10,	log_likelihood:-32432754.08
# 2019-07-20 17:37:07 INFO:GibbsSupervisedLDA:[ITER] 12,	MAE:0.09,	log_likelihood:-32321273.47
# 2019-07-20 17:41:23 INFO:GibbsSupervisedLDA:[ITER] 13,	MAE:0.09,	log_likelihood:-32213359.54
# 2019-07-20 17:45:41 INFO:GibbsSupervisedLDA:[ITER] 14,	MAE:0.10,	log_likelihood:-32111809.94
# 2019-07-20 17:49:57 INFO:GibbsSupervisedLDA:[ITER] 15,	MAE:0.09,	log_likelihood:-32011060.20
# 2019-07-20 17:54:12 INFO:GibbsSupervisedLDA:[ITER] 16,	MAE:0.10,	log_likelihood:-31909766.03
# 2019-07-20 17:58:27 INFO:GibbsSupervisedLDA:[ITER] 17,	MAE:0.10,	log_likelihood:-31813292.65
# 2019-07-20 18:02:43 INFO:GibbsSupervisedLDA:[ITER] 18,	MAE:0.10,	log_likelihood:-31721243.66
# 2019-07-20 18:06:59 INFO:GibbsSupervisedLDA:[ITER] 19,	MAE:0.10,	log_likelihood:-31625719.77
# 2019-07-20 18:11:14 INFO:GibbsSupervisedLDA:[ITER] 20,	MAE:0.10,	log_likelihood:-31530758.13
# 2019-07-20 18:15:29 INFO:GibbsSupervisedLDA:[ITER] 21,	MAE:0.10,	log_likelihood:-31443976.49
# 2019-07-20 18:19:42 INFO:GibbsSupervisedLDA:[ITER] 22,	MAE:0.10,	log_likelihood:-31351339.66
# 2019-07-20 18:23:58 INFO:GibbsSupervisedLDA:[ITER] 23,	MAE:0.10,	log_likelihood:-31265278.28
# 2019-07-20 18:28:14 INFO:GibbsSupervisedLDA:[ITER] 24,	MAE:0.10,	log_likelihood:-31178622.86
# 2019-07-20 18:32:29 INFO:GibbsSupervisedLDA:[ITER] 25,	MAE:0.10,	log_likelihood:-31095270.36
# 2019-07-20 18:36:47 INFO:GibbsSupervisedLDA:[ITER] 26,	MAE:0.10,	log_likelihood:-31009318.11
# 2019-07-20 18:41:02 INFO:GibbsSupervisedLDA:[ITER] 27,	MAE:0.10,	log_likelihood:-30925178.72
# 2019-07-20 18:45:18 INFO:GibbsSupervisedLDA:[ITER] 28,	MAE:0.10,	log_likelihood:-30843567.68
# 2019-07-20 18:49:33 INFO:GibbsSupervisedLDA:[ITER] 29,	MAE:0.10,	log_likelihood:-30760563.92
# 2019-07-20 18:53:48 INFO:GibbsSupervisedLDA:[ITER] 30,	MAE:0.10,	log_likelihood:-30679838.91
# 2019-07-20 18:58:03 INFO:GibbsSupervisedLDA:[ITER] 31,	MAE:0.10,	log_likelihood:-30601655.33
# 2019-07-20 19:02:21 INFO:GibbsSupervisedLDA:[ITER] 32,	MAE:0.10,	log_likelihood:-30526427.65
# 2019-07-20 19:06:41 INFO:GibbsSupervisedLDA:[ITER] 33,	MAE:0.10,	log_likelihood:-30451593.63
# 2019-07-20 19:10:57 INFO:GibbsSupervisedLDA:[ITER] 34,	MAE:0.10,	log_likelihood:-30378222.38
# 2019-07-20 19:15:12 INFO:GibbsSupervisedLDA:[ITER] 35,	MAE:0.09,	log_likelihood:-30303506.22
# 2019-07-20 19:19:28 INFO:GibbsSupervisedLDA:[ITER] 36,	MAE:0.09,	log_likelihood:-30232220.36
# 2019-07-20 19:23:42 INFO:GibbsSupervisedLDA:[ITER] 37,	MAE:0.09,	log_likelihood:-30161292.05
# 2019-07-20 19:27:57 INFO:GibbsSupervisedLDA:[ITER] 38,	MAE:0.09,	log_likelihood:-30089919.97
# 2019-07-20 19:32:11 INFO:GibbsSupervisedLDA:[ITER] 39,	MAE:0.10,	log_likelihood:-30021552.90
# 2019-07-20 19:36:26 INFO:GibbsSupervisedLDA:[ITER] 40,	MAE:0.10,	log_likelihood:-29952602.76
# 2019-07-20 19:40:41 INFO:GibbsSupervisedLDA:[ITER] 41,	MAE:0.10,	log_likelihood:-29885830.79
# 2019-07-20 19:44:57 INFO:GibbsSupervisedLDA:[ITER] 42,	MAE:0.09,	log_likelihood:-29821530.87
# 2019-07-20 19:49:13 INFO:GibbsSupervisedLDA:[ITER] 43,	MAE:0.09,	log_likelihood:-29755852.35
# 2019-07-20 19:53:28 INFO:GibbsSupervisedLDA:[ITER] 44,	MAE:0.09,	log_likelihood:-29695548.50
# 2019-07-20 19:57:45 INFO:GibbsSupervisedLDA:[ITER] 45,	MAE:0.09,	log_likelihood:-29629662.17
# 2019-07-20 20:02:00 INFO:GibbsSupervisedLDA:[ITER] 46,	MAE:0.09,	log_likelihood:-29565415.52
# 2019-07-20 20:06:16 INFO:GibbsSupervisedLDA:[ITER] 47,	MAE:0.09,	log_likelihood:-29502983.91
# 2019-07-20 20:10:30 INFO:GibbsSupervisedLDA:[ITER] 48,	MAE:0.10,	log_likelihood:-29444791.80
# 2019-07-20 20:14:45 INFO:GibbsSupervisedLDA:[ITER] 49,	MAE:0.09,	log_likelihood:-29386217.54
# 2019-07-20 20:19:00 INFO:GibbsSupervisedLDA:[ITER] 50,	MAE:0.10,	log_likelihood:-29324776.42
# 2019-07-20 20:23:16 INFO:GibbsSupervisedLDA:[ITER] 51,	MAE:0.10,	log_likelihood:-29267091.91
# 2019-07-20 20:27:31 INFO:GibbsSupervisedLDA:[ITER] 52,	MAE:0.10,	log_likelihood:-29211896.47
# 2019-07-20 20:31:46 INFO:GibbsSupervisedLDA:[ITER] 53,	MAE:0.10,	log_likelihood:-29152495.46
# 2019-07-20 20:36:02 INFO:GibbsSupervisedLDA:[ITER] 54,	MAE:0.10,	log_likelihood:-29088961.25
# 2019-07-20 20:40:17 INFO:GibbsSupervisedLDA:[ITER] 55,	MAE:0.10,	log_likelihood:-29020213.35
# 2019-07-20 20:44:32 INFO:GibbsSupervisedLDA:[ITER] 56,	MAE:0.09,	log_likelihood:-28959386.09
# 2019-07-20 20:48:47 INFO:GibbsSupervisedLDA:[ITER] 57,	MAE:0.09,	log_likelihood:-28903608.34
# 2019-07-20 20:53:02 INFO:GibbsSupervisedLDA:[ITER] 58,	MAE:0.09,	log_likelihood:-28845687.83
# 2019-07-20 20:57:17 INFO:GibbsSupervisedLDA:[ITER] 59,	MAE:0.09,	log_likelihood:-28795177.35
# 2019-07-20 21:01:31 INFO:GibbsSupervisedLDA:[ITER] 60,	MAE:0.09,	log_likelihood:-28743816.77
# 2019-07-20 21:05:46 INFO:GibbsSupervisedLDA:[ITER] 61,	MAE:0.09,	log_likelihood:-28694527.51
# 2019-07-20 21:10:02 INFO:GibbsSupervisedLDA:[ITER] 62,	MAE:0.09,	log_likelihood:-28648993.26
# 2019-07-20 21:14:17 INFO:GibbsSupervisedLDA:[ITER] 63,	MAE:0.09,	log_likelihood:-28602882.28
# 2019-07-20 21:18:32 INFO:GibbsSupervisedLDA:[ITER] 64,	MAE:0.09,	log_likelihood:-28559379.98
# 2019-07-20 21:22:48 INFO:GibbsSupervisedLDA:[ITER] 65,	MAE:0.09,	log_likelihood:-28520668.32
# 2019-07-20 21:27:02 INFO:GibbsSupervisedLDA:[ITER] 66,	MAE:0.09,	log_likelihood:-28478532.97
# 2019-07-20 21:31:19 INFO:GibbsSupervisedLDA:[ITER] 67,	MAE:0.09,	log_likelihood:-28438556.72
# 2019-07-20 21:35:33 INFO:GibbsSupervisedLDA:[ITER] 68,	MAE:0.09,	log_likelihood:-28397506.05
# 2019-07-20 21:39:48 INFO:GibbsSupervisedLDA:[ITER] 69,	MAE:0.09,	log_likelihood:-28355320.82
# 2019-07-20 21:44:04 INFO:GibbsSupervisedLDA:[ITER] 70,	MAE:0.09,	log_likelihood:-28311372.51
# 2019-07-20 21:48:18 INFO:GibbsSupervisedLDA:[ITER] 71,	MAE:0.09,	log_likelihood:-28273671.41
# 2019-07-20 21:52:33 INFO:GibbsSupervisedLDA:[ITER] 72,	MAE:0.09,	log_likelihood:-28234719.90
# 2019-07-20 21:56:48 INFO:GibbsSupervisedLDA:[ITER] 73,	MAE:0.09,	log_likelihood:-28197568.33
# 2019-07-20 22:01:04 INFO:GibbsSupervisedLDA:[ITER] 74,	MAE:0.09,	log_likelihood:-28161567.52
# 2019-07-20 22:05:20 INFO:GibbsSupervisedLDA:[ITER] 75,	MAE:0.09,	log_likelihood:-28125588.49
# 2019-07-20 22:09:36 INFO:GibbsSupervisedLDA:[ITER] 76,	MAE:0.09,	log_likelihood:-28093225.88
# 2019-07-20 22:13:51 INFO:GibbsSupervisedLDA:[ITER] 77,	MAE:0.09,	log_likelihood:-28056889.03
# 2019-07-20 22:18:04 INFO:GibbsSupervisedLDA:[ITER] 78,	MAE:0.09,	log_likelihood:-28028627.59
# 2019-07-20 22:22:18 INFO:GibbsSupervisedLDA:[ITER] 79,	MAE:0.09,	log_likelihood:-27999703.15
# 2019-07-20 22:26:33 INFO:GibbsSupervisedLDA:[ITER] 80,	MAE:0.09,	log_likelihood:-27971702.64
# 2019-07-20 22:30:48 INFO:GibbsSupervisedLDA:[ITER] 81,	MAE:0.09,	log_likelihood:-27948152.72
# 2019-07-20 22:35:03 INFO:GibbsSupervisedLDA:[ITER] 82,	MAE:0.09,	log_likelihood:-27927578.10
# 2019-07-20 22:39:16 INFO:GibbsSupervisedLDA:[ITER] 83,	MAE:0.09,	log_likelihood:-27907872.48
# 2019-07-20 22:43:33 INFO:GibbsSupervisedLDA:[ITER] 84,	MAE:0.09,	log_likelihood:-27885968.08
# 2019-07-20 22:47:46 INFO:GibbsSupervisedLDA:[ITER] 85,	MAE:0.09,	log_likelihood:-27866367.84
# 2019-07-20 22:51:59 INFO:GibbsSupervisedLDA:[ITER] 86,	MAE:0.09,	log_likelihood:-27846421.60
# 2019-07-20 22:56:14 INFO:GibbsSupervisedLDA:[ITER] 87,	MAE:0.09,	log_likelihood:-27830322.59
# 2019-07-20 23:00:29 INFO:GibbsSupervisedLDA:[ITER] 88,	MAE:0.09,	log_likelihood:-27808587.28
# 2019-07-20 23:04:44 INFO:GibbsSupervisedLDA:[ITER] 89,	MAE:0.09,	log_likelihood:-27791465.96
# 2019-07-20 23:08:57 INFO:GibbsSupervisedLDA:[ITER] 90,	MAE:0.09,	log_likelihood:-27773723.46
# 2019-07-20 23:13:12 INFO:GibbsSupervisedLDA:[ITER] 91,	MAE:0.09,	log_likelihood:-27756539.06
# 2019-07-20 23:17:26 INFO:GibbsSupervisedLDA:[ITER] 92,	MAE:0.09,	log_likelihood:-27741295.96
# 2019-07-20 23:21:40 INFO:GibbsSupervisedLDA:[ITER] 93,	MAE:0.09,	log_likelihood:-27723492.40
# 2019-07-20 23:25:55 INFO:GibbsSupervisedLDA:[ITER] 94,	MAE:0.09,	log_likelihood:-27704072.33
# 2019-07-20 23:30:10 INFO:GibbsSupervisedLDA:[ITER] 95,	MAE:0.08,	log_likelihood:-27686563.25
# 2019-07-20 23:34:25 INFO:GibbsSupervisedLDA:[ITER] 96,	MAE:0.08,	log_likelihood:-27666529.69
# Eta 4.50097118727414 Topic 13 :	 fakenews,racist,senator,national,great,acosta,dani,help,fight,way,hey,democrat,real,nfl,retweet

# %%
model_2016= GibbsSupervisedLDA(n_doc_2016, n_voca_2016, n_topic, sigma=r_var)
model_2016.fit(corpus_2016, ratings_2016)

voca = []
for i in range(n_voca_2016):
    voca.append(dictionary_2016[i])

for ti in model_2016.eta.argsort():
    top_words = get_top_words(model_2016.TW, voca, ti, n_words=15)
    print('Eta', model_2016.eta[ti] ,'Topic', ti ,':\t', ','.join(top_words))
# Out:
# 2019-10-15 11:37:08 INFO:GibbsSupervisedLDA:[ITER] 0,	MAE:0.11,	log_likelihood:-24844408.23
# 2019-10-15 11:38:57 INFO:GibbsSupervisedLDA:[ITER] 1,	MAE:0.10,	log_likelihood:-24309675.14
# 2019-10-15 11:40:43 INFO:GibbsSupervisedLDA:[ITER] 2,	MAE:0.10,	log_likelihood:-24005065.00
# 2019-10-15 11:42:31 INFO:GibbsSupervisedLDA:[ITER] 3,	MAE:0.10,	log_likelihood:-23791378.78
# 2019-10-15 11:44:21 INFO:GibbsSupervisedLDA:[ITER] 4,	MAE:0.10,	log_likelihood:-23618600.76
# 2019-10-15 11:46:08 INFO:GibbsSupervisedLDA:[ITER] 5,	MAE:0.10,	log_likelihood:-23474751.61
# 2019-10-15 11:47:56 INFO:GibbsSupervisedLDA:[ITER] 6,	MAE:0.10,	log_likelihood:-23349148.26
# 2019-10-15 11:49:43 INFO:GibbsSupervisedLDA:[ITER] 7,	MAE:0.10,	log_likelihood:-23235948.03
# 2019-10-15 11:51:31 INFO:GibbsSupervisedLDA:[ITER] 8,	MAE:0.10,	log_likelihood:-23127028.31
# 2019-10-15 11:53:17 INFO:GibbsSupervisedLDA:[ITER] 9,	MAE:0.10,	log_likelihood:-23030741.67
# 2019-10-15 11:55:07 INFO:GibbsSupervisedLDA:[ITER] 10,	MAE:0.10,	log_likelihood:-22940035.39
# 2019-10-15 11:56:56 INFO:GibbsSupervisedLDA:[ITER] 11,	MAE:0.10,	log_likelihood:-22849143.33
# 2019-10-15 11:58:45 INFO:GibbsSupervisedLDA:[ITER] 12,	MAE:0.10,	log_likelihood:-22766731.63
# 2019-10-15 12:00:33 INFO:GibbsSupervisedLDA:[ITER] 13,	MAE:0.10,	log_likelihood:-22688146.10
# 2019-10-15 12:02:23 INFO:GibbsSupervisedLDA:[ITER] 14,	MAE:0.10,	log_likelihood:-22609863.95
# 2019-10-15 12:04:13 INFO:GibbsSupervisedLDA:[ITER] 15,	MAE:0.10,	log_likelihood:-22534805.36
# 2019-10-15 12:06:00 INFO:GibbsSupervisedLDA:[ITER] 16,	MAE:0.10,	log_likelihood:-22459057.17
# 2019-10-15 12:07:47 INFO:GibbsSupervisedLDA:[ITER] 17,	MAE:0.10,	log_likelihood:-22386692.44
# 2019-10-15 12:09:32 INFO:GibbsSupervisedLDA:[ITER] 18,	MAE:0.10,	log_likelihood:-22313452.60
# 2019-10-15 12:11:16 INFO:GibbsSupervisedLDA:[ITER] 19,	MAE:0.10,	log_likelihood:-22240187.98
# 2019-10-15 12:13:01 INFO:GibbsSupervisedLDA:[ITER] 20,	MAE:0.10,	log_likelihood:-22171940.04
# 2019-10-15 12:14:46 INFO:GibbsSupervisedLDA:[ITER] 21,	MAE:0.10,	log_likelihood:-22098352.55
# 2019-10-15 12:16:33 INFO:GibbsSupervisedLDA:[ITER] 22,	MAE:0.10,	log_likelihood:-22026135.72
# 2019-10-15 12:18:18 INFO:GibbsSupervisedLDA:[ITER] 23,	MAE:0.10,	log_likelihood:-21957942.54
# 2019-10-15 12:20:04 INFO:GibbsSupervisedLDA:[ITER] 24,	MAE:0.10,	log_likelihood:-21891053.07
# 2019-10-15 12:21:51 INFO:GibbsSupervisedLDA:[ITER] 25,	MAE:0.10,	log_likelihood:-21822685.09
# 2019-10-15 12:23:36 INFO:GibbsSupervisedLDA:[ITER] 26,	MAE:0.10,	log_likelihood:-21760173.83
# 2019-10-15 12:25:22 INFO:GibbsSupervisedLDA:[ITER] 27,	MAE:0.10,	log_likelihood:-21699931.65
# 2019-10-15 12:27:09 INFO:GibbsSupervisedLDA:[ITER] 28,	MAE:0.10,	log_likelihood:-21639533.21
# 2019-10-15 12:28:57 INFO:GibbsSupervisedLDA:[ITER] 29,	MAE:0.10,	log_likelihood:-21579627.37
# 2019-10-15 12:30:47 INFO:GibbsSupervisedLDA:[ITER] 30,	MAE:0.10,	log_likelihood:-21524364.03
# 2019-10-15 12:32:33 INFO:GibbsSupervisedLDA:[ITER] 31,	MAE:0.10,	log_likelihood:-21467246.78
# 2019-10-15 12:34:19 INFO:GibbsSupervisedLDA:[ITER] 32,	MAE:0.10,	log_likelihood:-21415182.47
# 2019-10-15 12:36:06 INFO:GibbsSupervisedLDA:[ITER] 33,	MAE:0.10,	log_likelihood:-21362589.00
# 2019-10-15 12:37:54 INFO:GibbsSupervisedLDA:[ITER] 34,	MAE:0.10,	log_likelihood:-21311951.01
# 2019-10-15 12:39:38 INFO:GibbsSupervisedLDA:[ITER] 35,	MAE:0.10,	log_likelihood:-21265317.80
# 2019-10-15 12:41:23 INFO:GibbsSupervisedLDA:[ITER] 36,	MAE:0.10,	log_likelihood:-21219819.71
# 2019-10-15 12:43:14 INFO:GibbsSupervisedLDA:[ITER] 37,	MAE:0.10,	log_likelihood:-21169218.11
# 2019-10-15 12:45:00 INFO:GibbsSupervisedLDA:[ITER] 38,	MAE:0.09,	log_likelihood:-21127777.52
# 2019-10-15 12:46:47 INFO:GibbsSupervisedLDA:[ITER] 39,	MAE:0.09,	log_likelihood:-21085652.07
# 2019-10-15 12:48:32 INFO:GibbsSupervisedLDA:[ITER] 40,	MAE:0.09,	log_likelihood:-21044232.13
# 2019-10-15 12:50:20 INFO:GibbsSupervisedLDA:[ITER] 41,	MAE:0.09,	log_likelihood:-21001814.37
# 2019-10-15 12:52:05 INFO:GibbsSupervisedLDA:[ITER] 42,	MAE:0.09,	log_likelihood:-20964109.11
# 2019-10-15 12:53:53 INFO:GibbsSupervisedLDA:[ITER] 43,	MAE:0.09,	log_likelihood:-20934609.81
# 2019-10-15 12:55:39 INFO:GibbsSupervisedLDA:[ITER] 44,	MAE:0.09,	log_likelihood:-20901534.10
# 2019-10-15 12:57:28 INFO:GibbsSupervisedLDA:[ITER] 45,	MAE:0.09,	log_likelihood:-20872367.92
# 2019-10-15 12:59:18 INFO:GibbsSupervisedLDA:[ITER] 46,	MAE:0.09,	log_likelihood:-20838760.48
# 2019-10-15 13:01:05 INFO:GibbsSupervisedLDA:[ITER] 47,	MAE:0.09,	log_likelihood:-20809902.05
# 2019-10-15 13:02:51 INFO:GibbsSupervisedLDA:[ITER] 48,	MAE:0.09,	log_likelihood:-20781560.05
# 2019-10-15 13:04:35 INFO:GibbsSupervisedLDA:[ITER] 49,	MAE:0.09,	log_likelihood:-20753688.70
# 2019-10-15 13:06:22 INFO:GibbsSupervisedLDA:[ITER] 50,	MAE:0.09,	log_likelihood:-20726935.31
# 2019-10-15 13:08:09 INFO:GibbsSupervisedLDA:[ITER] 51,	MAE:0.09,	log_likelihood:-20703670.14
# 2019-10-15 13:09:55 INFO:GibbsSupervisedLDA:[ITER] 52,	MAE:0.09,	log_likelihood:-20679954.56
# 2019-10-15 13:11:41 INFO:GibbsSupervisedLDA:[ITER] 53,	MAE:0.09,	log_likelihood:-20656841.26
# 2019-10-15 13:13:26 INFO:GibbsSupervisedLDA:[ITER] 54,	MAE:0.09,	log_likelihood:-20634049.34
# 2019-10-15 13:15:11 INFO:GibbsSupervisedLDA:[ITER] 55,	MAE:0.09,	log_likelihood:-20615045.03
# 2019-10-15 13:16:55 INFO:GibbsSupervisedLDA:[ITER] 56,	MAE:0.09,	log_likelihood:-20595067.31
# 2019-10-15 13:18:41 INFO:GibbsSupervisedLDA:[ITER] 57,	MAE:0.09,	log_likelihood:-20574513.51
# 2019-10-15 13:20:26 INFO:GibbsSupervisedLDA:[ITER] 58,	MAE:0.09,	log_likelihood:-20559573.91
# 2019-10-15 13:22:10 INFO:GibbsSupervisedLDA:[ITER] 59,	MAE:0.09,	log_likelihood:-20538579.49
# 2019-10-15 13:23:54 INFO:GibbsSupervisedLDA:[ITER] 60,	MAE:0.09,	log_likelihood:-20522299.97
# 2019-10-15 13:25:39 INFO:GibbsSupervisedLDA:[ITER] 61,	MAE:0.09,	log_likelihood:-20505157.77
# 2019-10-15 13:27:24 INFO:GibbsSupervisedLDA:[ITER] 62,	MAE:0.09,	log_likelihood:-20491273.95
# 2019-10-15 13:29:09 INFO:GibbsSupervisedLDA:[ITER] 63,	MAE:0.09,	log_likelihood:-20472213.95
# 2019-10-15 13:30:54 INFO:GibbsSupervisedLDA:[ITER] 64,	MAE:0.09,	log_likelihood:-20455948.51
# 2019-10-15 13:32:38 INFO:GibbsSupervisedLDA:[ITER] 65,	MAE:0.09,	log_likelihood:-20440580.79
# 2019-10-15 13:34:22 INFO:GibbsSupervisedLDA:[ITER] 66,	MAE:0.09,	log_likelihood:-20429038.97
# 2019-10-15 13:36:07 INFO:GibbsSupervisedLDA:[ITER] 67,	MAE:0.09,	log_likelihood:-20413997.86
# 2019-10-15 13:37:54 INFO:GibbsSupervisedLDA:[ITER] 68,	MAE:0.09,	log_likelihood:-20401455.61
# 2019-10-15 13:39:38 INFO:GibbsSupervisedLDA:[ITER] 69,	MAE:0.09,	log_likelihood:-20385613.86
# 2019-10-15 13:41:24 INFO:GibbsSupervisedLDA:[ITER] 70,	MAE:0.09,	log_likelihood:-20376880.38
# 2019-10-15 13:43:09 INFO:GibbsSupervisedLDA:[ITER] 71,	MAE:0.09,	log_likelihood:-20364723.55
# 2019-10-15 13:44:54 INFO:GibbsSupervisedLDA:[ITER] 72,	MAE:0.09,	log_likelihood:-20352336.85
# 2019-10-15 13:46:38 INFO:GibbsSupervisedLDA:[ITER] 73,	MAE:0.09,	log_likelihood:-20340465.89
# 2019-10-15 13:48:23 INFO:GibbsSupervisedLDA:[ITER] 74,	MAE:0.09,	log_likelihood:-20326022.82
# 2019-10-15 13:50:08 INFO:GibbsSupervisedLDA:[ITER] 75,	MAE:0.09,	log_likelihood:-20317282.41
# 2019-10-15 13:51:55 INFO:GibbsSupervisedLDA:[ITER] 76,	MAE:0.09,	log_likelihood:-20304479.66
# 2019-10-15 13:53:40 INFO:GibbsSupervisedLDA:[ITER] 77,	MAE:0.09,	log_likelihood:-20294053.32
# 2019-10-15 13:55:24 INFO:GibbsSupervisedLDA:[ITER] 78,	MAE:0.09,	log_likelihood:-20284244.40
# 2019-10-15 13:57:08 INFO:GibbsSupervisedLDA:[ITER] 79,	MAE:0.09,	log_likelihood:-20273946.40
# 2019-10-15 13:58:53 INFO:GibbsSupervisedLDA:[ITER] 80,	MAE:0.09,	log_likelihood:-20262306.16
# 2019-10-15 14:00:39 INFO:GibbsSupervisedLDA:[ITER] 81,	MAE:0.09,	log_likelihood:-20252065.60
# 2019-10-15 14:02:27 INFO:GibbsSupervisedLDA:[ITER] 82,	MAE:0.09,	log_likelihood:-20240685.97
# 2019-10-15 14:04:13 INFO:GibbsSupervisedLDA:[ITER] 83,	MAE:0.09,	log_likelihood:-20236377.86
# 2019-10-15 14:06:03 INFO:GibbsSupervisedLDA:[ITER] 84,	MAE:0.09,	log_likelihood:-20226056.63
# 2019-10-15 14:07:50 INFO:GibbsSupervisedLDA:[ITER] 85,	MAE:0.09,	log_likelihood:-20217296.65
# 2019-10-15 14:09:38 INFO:GibbsSupervisedLDA:[ITER] 86,	MAE:0.09,	log_likelihood:-20208166.86
# 2019-10-15 14:11:22 INFO:GibbsSupervisedLDA:[ITER] 87,	MAE:0.09,	log_likelihood:-20202994.62
# 2019-10-15 14:13:09 INFO:GibbsSupervisedLDA:[ITER] 88,	MAE:0.09,	log_likelihood:-20196445.55
# 2019-10-15 14:14:58 INFO:GibbsSupervisedLDA:[ITER] 89,	MAE:0.09,	log_likelihood:-20183155.63
# 2019-10-15 14:16:43 INFO:GibbsSupervisedLDA:[ITER] 90,	MAE:0.09,	log_likelihood:-20177848.92
# 2019-10-15 14:18:32 INFO:GibbsSupervisedLDA:[ITER] 91,	MAE:0.09,	log_likelihood:-20169246.60
# Eta 1.5918041120057462 Topic 7 :	 ccot,gopdebate,gop,stopthegop,win,debate,teaparty,donald,cruz,wakeupamerica,cruzcrew,poll,president,tedcruz,think
# Eta 1.8856482707174684 Topic 6 :	 media,news,cnn,twitter,look,watch,go,tweet,get,bomb,video,use,post,fake,think
# Eta 2.9296635465743677 Topic 19 :	 america,thank,great,president,live,day,hillaryclinton,stand,freedom,world,support,good,free,let,honor
# Eta 4.607736463266668 Topic 15 :	 year,think,get,win,old,america,kill,look,man,women,pay,years,live,stop,war

# %%
model_2015= GibbsSupervisedLDA(n_doc_2015, n_voca_2015, n_topic, sigma=r_var)
model_2015.fit(corpus_2015, ratings_2015)

voca = []
for i in range(n_voca_2015):
    voca.append(dictionary_2015[i])

for ti in model_2015.eta.argsort():
    top_words = get_top_words(model_2015.TW, voca, ti, n_words=15)
    print('Eta', model_2015.eta[ti] ,'Topic', ti ,':\t', ','.join(top_words))

# %%
max_iter = 100
h_doc_topic_sum_2017 = model_2017.sample_heldout_doc(max_iter, test_corpus_2017)

# Normalise topic assignments
normalised_topic_assi_2017 = h_doc_topic_sum_2017
length = len(h_doc_topic_sum_2017)
for i in range(length):
    sum = 0
    l = len(h_doc_topic_sum_2017[i])
    for j in range(l):
        sum += h_doc_topic_sum_2017[i][j]
    for j in range(l):
        normalised_topic_assi_2017[i][j] = h_doc_topic_sum_2017[i][j] / sum
        
        
predicted_value_2017 = normalised_topic_assi_2017 .dot (model_2017.eta)

for i in range(len(predicted_value_2017)):
    if predicted_value_2017[i] > 0:
        predicted_value_2017[i] = 1
    elif predicted_value_2017[i] < 0:
        predicted_value_2017[i] = -1

mae_2017 = np.mean(np.abs(test_ratings_2017 - predicted_value_2017))
mae_2017
# Out:
# 0.741528676389955

# %%
max_iter = 100
h_doc_topic_sum_2016 = model_2016.sample_heldout_doc(max_iter, test_corpus_2016)

# Normalise topic assignments
normalised_topic_assi_2016 = h_doc_topic_sum_2016
length = len(h_doc_topic_sum_2016)
for i in range(length):
    sum = 0
    l = len(h_doc_topic_sum_2016[i])
    for j in range(l):
        sum += h_doc_topic_sum_2016[i][j]
    for j in range(l):
        normalised_topic_assi_2016[i][j] = h_doc_topic_sum_2016[i][j] / sum
        
        
predicted_value_2016 = normalised_topic_assi_2016 .dot (model_2016.eta)

for i in range(len(predicted_value_2016)):
    if predicted_value_2016[i] > 0:
        predicted_value_2016[i] = 1
    elif predicted_value_2016[i] < 0:
        predicted_value_2016[i] = -1

mae_2016 = np.mean(np.abs(test_ratings_2016 - predicted_value_2016))
mae_2016
# Out:
# 0.9821167510964539

# %%
max_iter = 100
h_doc_topic_sum_2015 = model_2015.sample_heldout_doc(max_iter, test_corpus)

# Normalise topic assignments
normalised_topic_assi_2015 = h_doc_topic_sum_2015
length = len(h_doc_topic_sum_2015)
for i in range(length):
    sum = 0
    l = len(h_doc_topic_sum_2015[i])
    for j in range(l):
        sum += h_doc_topic_sum_2015[i][j]
    for j in range(l):
        normalised_topic_assi_2015[i][j] = h_doc_topic_sum_2015[i][j] / sum
        
        
predicted_value_2015 = normalised_topic_assi_2015 .dot (model_2015.eta)

for i in range(len(predicted_value_2015)):
    if predicted_value_2015[i] > 0:
        predicted_value_2015[i] = 1
    elif predicted_value_2015[i] < 0:
        predicted_value_2015[i] = -1

mae_2015 = np.mean(np.abs(test_ratings - predicted_value_2015))
mae_2015

# %% [markdown]
# Sentiment analysis

# %%
# For 2016
# Normalise DT
normalised_DT = model_2016.DT
length = len(model_2016.DT)
for i in range(length):
    sum = 0
    l = len(model_2016.DT[i])
    for j in range(l):
        sum += model_2016.DT[i][j]
    for j in range(l):
        normalised_DT[i][j] = model_2016.DT[i][j] / sum

# %%
interested_topic = 1
threshold = 0.5
corpus_2016 = []
for i in range(len(normalised_DT)):
    if normalised_DT[i][interested_topic] >= threshold:
        corpus_2016.append(df_tweets_2016.loc[i, 'content'])

# %%
for i in range(len(corpus_2016)):
    print(corpus_2016[i])
    print(sentiment(corpus_2016[i]))
# Out:
# Prince Philip isn't happy about being a stay-at-home dad? #TheCrown
# ('neg', 1.0)
# on today's episode i introduce the world to my own version of sasha fiece: Lola LaFway. she's still pretty awkward but its cool
# ('neg', 1.0)
# RT @MezCPA: MT @CalFreedomMom: To save America, we must turn to God through His Son, Jesus Christ. #ccot https://t.co/udRxe4Cnun #RenewUS #…
# ('pos', 0.8)
# #TCOT You Can Almost Feel Their Giddy Glee https://t.co/s81EYODIZg
# ('neg', 1.0)
# You need to shut up and shave that shit off your face! https://t.co/5Wp7ucyfAa
# ('pos', 1.0)
# #CCOT "It is impossible to mentally or socially enslave a Bible-reading people."  ~ Horace Greeley #freedom #liberty #politics
# ('pos', 0.8)
# RT @PatriotGinger2: MT @TimBurt: '...And if someone asks about your Christian hope, always be ready to explain it' https://t.co/IJKmn6bmX6 …
# ('neg', 1.0)
# People 'love nature' until it crawls up their leg
# ('pos', 1.0)
# Fabulous reads from little tykes to grandma #thrillers #chillers & #Romance  https://t.co/j7c4XsImRW  #CR4U
# ('pos', 1.0)
# Isaiah 57:15 "I restore the crushed spirit of the humble and revive the courage of those with repentant hearts."
# ('neg', 0.8)
# Philippians 2:15 "Live clean, innocent lives as children of God, shining like bright lights in a world full of crooked and perverse people"
# ('pos', 0.6)
# Let the heavens declare His righteousness, For God Himself is Judge. Psalm 50:6 https://t.co/e4HebUiRsi
# ('neg', 1.0)
# Now faith is being sure we will get what we hope for. It is being sure of what we cannot see. Hebrews 11:1 https://t.co/yPRGsqwW6H
# ('neg', 1.0)
# God on global warming.  "For the world is Mine, and all its fullness." Psalm 50:12b God's  Word proven 100% true. https://t.co/PvUSUMO8NP
# ('neg', 1.0)
# Who cares? How about the disaster the US is in right now? How about focusing on important issues.. Good God! #Loser  https://t.co/WxWvko9e1m
# ('neg', 1.0)
# RT @DrSueDVM: You don't learn that Christ is all you need, until Christ is all you have.  #RenewUS #PJNET #ccot #PrayForAmerica
# ('pos', 1.0)
# Are they going to play the race card every year? #OscarHasNoColor https://t.co/Sab7ezKlY8
# ('pos', 0.6)
# RT @mcspocky: Republicans… #UniteBlue #TopProg #LibCrib #p2 #tcot https://t.co/whDioZaatw
# ('neg', 1.0)
# '@Braveheart_USA #PatriotsMarchOnDC Contact: Web► https://t.co/exWSOZxq6V Donate► https://t.co/sFjc0fLnMU #tcot #ccot https://t.co/vtxEjcmUHW'
# ('neg', 1.0)
# Word is @JohnKasich 's internals r looking good-we know that might be true is bc @JebBush is now out w/ contrast ad  https://t.co/IQVh9F2ZGn
# ('pos', 1.0)
# '@ChuckNellis @Larryputt @tgradous @leeone_roz @pjamesjp1 @marylene58 @JVER1 @LVNancy @Shooters_Wife @Bobbyh214  https://t.co/bD1W8DuDfT'
# ('neg', 1.0)
# Cruz on securing America  #VOAV #CruzCrew  https://t.co/SoeHCFCjaf … https://t.co/zUAmLSxazs
# ('neg', 1.0)
# https://t.co/sJrw08glRz Cruz on preserving life, marriage, family #VOAV #CruzCrew
# ('neg', 1.0)
# God has wonderful ways have helping you grow in Him! SHORT READ: "This is God's Way of Fortifying Your Life"   https://t.co/ONBFUvbuYk
# ('neg', 1.0)
# Our days should be temples for the presence of God. Not vehicles for our own pleasure. ~Dr Rich Kincl
# ('neg', 1.0)
# Quote of the Day: One of the penalties for refusing to participate in politics is that you end up being governed by your inferiors!    Plato
# ('neg', 1.0)
# #RealLifeMagicSpells  Abracadabra! ...  no  Hocus Po...  no  Rapple-Dapp....  no  *wiggles nose ...  nope.  Oh. Wait.  Bring-It-In-Y'all ! https://t.co/NlZdU3pFLe
# ('pos', 1.0)
# NoTrumpeounus! To make all of your Trump supporting relatives not mention his name at #thanksgiving & #Christmas #RealLifeMagicSpells
# ('neg', 1.0)
# Harmony knows Aaron thinks she's just a friend. What if she's wrong? THE FRIENDSHIP SERIES https://t.co/fORjLlLYA8 #Kindle #KDP
# ('pos', 1.0)
# '@nitroxnut @FoxNews @HomeDepot God I hope she loses!!'
# ('neg', 1.0)
# If you are going to read one message from Heaven before #myvote2016 on #ElectionDay , read this one: https://t.co/7tWILT5kpk
# ('neg', 1.0)
# We had a wonderful time! So grateful to Lissa &amp; Brad @politicsprose for a lovely evening. #SettleForMore https://t.co/mXYcLBsnNJ
# ('neg', 1.0)
# Sex Is People's Downfall. Jesus Said 'They Who Are Born of God Keep Their Seed Within Them' https://t.co/McRobVcN3k
# ('neg', 1.0)
# Trump Cheered at Christmas Eve Mass... https://t.co/cp1DRtJiiQ
# ('neg', 1.0)
# Classless Chrissy Teigen wants Trump to know fabulously rich, spoiled ‘celebs are people too’ https://t.co/WyxqoEwsLB https://t.co/0zIxPa3jwq
# ('neg', 1.0)
# 6 Stretches You Should Do Before Getting Out of Bed to Feel Great All Day https://t.co/qWkVCkS5RS
# ('neg', 0.8)
# Christina Milian Nipple Show In Super Sheer Dress https://t.co/GhnARuJQGp
# ('neg', 1.0)
# Wonder if this guy is black? They always bring up the past. And faithfully omit the parts that offend them.  https://t.co/EbumYHVTtA
# ('pos', 0.6)
# RT @PatriotGinger2: MT @TBV_Post: And that every tongue should confess that Jesus Christ is LORD... https://t.co/XuP5EX2KSQ #RenewUS #PJNET
# ('pos', 0.8)
# John 14:27 Peace I leave with you; My peace I give you; not as the world gives do I give to you.  Do not let your heart be troubled,...
# ('neg', 1.0)
# RT @nanajill211: Just had to RT this.  And it just goes on and on and on.  @tedcruz #CruzCrew #PJNET Off color a little but funny. https://…
# ('neg', 1.0)
# I caught it too!!!!  That I can tell you. I can tell you that. https://t.co/cJVOIlyinB
# ('neg', 1.0)
# Texas is looking better by the day for Trump, everybody I talk to likes Trump, the "liar" label on Ted is having an impact, TX for truth
# ('neg', 1.0)
# The color of the skin is in no way connected with strength of the mind or intellectual powers! #OscarHasNoColor
# ('neg', 1.0)
# RT @DrSueDVM: You don't learn that Christ is all you need, until Christ is all you have.  #RenewUS #PJNET #ccot #PrayForAmerica
# ('pos', 1.0)
# Yall see the Illuminati pushing the gay agenda with all this rainbow stuff? #SuperBowl50 #StayWoke
# ('neg', 1.0)
# #FLprimary #OhioPrimary #MIPrimary #IllinoisPrimary #MSprimary #ncprimary #IDprimary #UniteWithCruz  #StopTrump   https://t.co/ZqxG88q3lI
# ('neg', 1.0)
# #DStrong Dorian has one wish before he dies of cancer: to be famous. Please RETWEET this message of love. https://t.co/8ydoeQatLM
# ('pos', 0.8)
# RT @AboutTheChild: MT @TimBurt: If you love Jesus, feel free to boldly retweet it and proclaim it! https://t.co/dRldxUQQQV #RenewUS #PJNET
# ('neg', 1.0)
# MT @Love4Military: For Those Who Will Never Feel Their Homeland Beneath Their Feet Again.... https://t.co/x3Cjeis2tk #InHonorOf #PJNET
# ('neg', 1.0)
# MT @starlately: Greater love has none than this: that he lay down his life for his friends. https://t.co/hzxM80XHCZ #InHonorOf #PJNET
# ('neg', 1.0)
# '@jstines3 @Mike_Rosenboom @ChuckNellis  Quoting Prager: 2 doors: 1 marked "Man-eating lion" 1 marked "MAYBE man eating lion" You must open 1'
# ('neg', 0.8)
# By the GRACE OF GOD we are FORGIVEN!   #PJNET #RenewUS     https://t.co/2RnqgaVe5J
# ('neg', 1.0)
# Thank God for The Lox I've learned money ain't shit respect is everything!
# ('pos', 1.0)
# I'm 40 years old today. I still don't understand why getting older freaks some people out. This is fun.
# ('pos', 1.0)
# "Writing as writing.   Writing as rioting.   Writing as righting.   On the best days, all three."   – Teju Cole
# ('neg', 1.0)
# God send me an angel, from the heavens above, send me an angel to heal my broken heart, for being in love.
# ('pos', 1.0)
# *** #Black #Conservative *** Urban #Family Talk Radio --> Truth Wisdom = Empowerment  https://t.co/SZTRfKsoRY  #PJNET #CCOT
# ('neg', 1.0)
# RT @vietrandy: Jesus is coming! #Maranatha #Rapture #Judgment #Tribulation #2ndAdvent #MillennialKingdom #eternity #ccot https://t.co/S3pDD…
# ('neg', 1.0)
# '@SissyWillis @hipEchik Some of it I can appreciate, a bit: Localism, a sense of place. There's such an edge these days, though.'
# ('neg', 1.0)
# Viral Photos Show Bride and Groom Surprising Grandma in the Hospital on Their Wedding Day: Recently, a charmin... https://t.co/Ztbrrcnnns
# ('neg', 1.0)
# God Bless #Patriots  Man Said "We need a King"  God Said "No You Don't"  @JMontanaPOTL @SMolloyDVM @GenGSPatton ���� https://t.co/UVsWKHiEcl
# ('pos', 0.6)
# .@realDonaldTrump is no more "finished" than Bill Clinton was after the Gennifer Flowers scandal--wishing it to be true doesn't make it true
# ('pos', 1.0)
# #Trump says he is very sorry. As ✝Christians, we believe in redemption + forgiveness. �� https://t.co/t7c7P8AyX2
# ('pos', 1.0)
# Dear @realDonaldTrump stop mentioning @BernieSanders voters,  We will NEVER NEVER vote for you, you piece of crap.  @ChuckNellis
# ('neg', 1.0)
# 'They were the WORST we've EVER tested...' - Frank Luntz #NeverTrumpOrHillary https://t.co/RHjgbz5uZD
# ('neg', 1.0)
# '@RWSurferGirl1 @RogerJStoneJr @DRJAMESCABOT @JaredWyand @kupajo322 WE MUST DONATE DIRECTLY TO TRUMP TODAY ��� RT ALL https://t.co/Wuy1d40lHn'
# ('neg', 1.0)
# It's so cute when Hollywood "celebrities" tell us all who to vote for https://t.co/7P4sVD2RxX
# ('neg', 1.0)
# '@HillaryClinton You just want Latinos washing your laundry and cooking for you!  You never went to visit the #Louisianafloodvictims'
# ('neg', 1.0)
# '@SSC1974 @MichelleObama Didn't mean to offend, sorry. My belief is that God knows what's in my heart and doesn't take offense :)'
# ('pos', 1.0)
# Nobel Prize for Chemistry goes to Keith Richards
# ('neg', 1.0)
# Thanks for the recent follow @CherryFyre @RattlesnakeX @need2knowu Happy to connect :) have a great Friday. >> https://t.co/8xDQ5dffMV
# ('neg', 1.0)
# This happened to me in NHL 15 and I was so pissed at how fake of a goal it was...but now this video has changed my life for the better https://t.co/B8KnChhbiH
# ('pos', 1.0)
# Please RT: Hey #Christians in #Colorado, are you ready to stand up for #Jesus and let @HillaryClinton know that #ShePickedTheWrongFight? https://t.co/0qdIjxtG3Q
# ('neg', 1.0)
# Jerry Falwell Jr: "I don't believe these women's accounts. The timing is too convenient" Last tweet on #FakeTrumpVictims.  #PodestaEmails7 https://t.co/2yRxMERaeQ
# ('neg', 1.0)
# Donald Trump will keep his promise to us and help us make America great again!!! God bless you Donald!!! @realDonaldTrump @mike_pence https://t.co/mZfz1CVFzl
# ('neg', 1.0)
# They should have carried out checks on teeth, and  I hope they have had Finger Printing and DNA checks! https://t.co/blw4Axn31E
# ('pos', 1.0)
# '@Kurt_Vonnegut @The_Geb you would get the rewards on earth. Plato gives good reasoning for being decent. As does our nature.'
# ('neg', 1.0)
# '@truth_told_now OMG! But my lib friends tell me she is so intelligent!'
# ('neg', 1.0)
# "So you guys bathe in that hypocrisy if you want to. I’d just like to hear how the debate went." https://t.co/hcxHOXbdLu
# ('pos', 0.6)
# The #book that changed #JaneEyre forever. Happy Birthday "Wide Sargasso Sea"!� A novel that dared take on a #classic https://t.co/LcdADSCaip https://t.co/Rl148nEkVx
# ('neg', 1.0)
# It's so cute when Hollywood "celebrities" tell us all who to vote for https://t.co/7P4sVD2RxX
# ('neg', 1.0)
# '@RWSurferGirl1 @RogerJStoneJr @DRJAMESCABOT @JaredWyand @kupajo322 WE MUST DONATE DIRECTLY TO TRUMP TODAY ��� RT ALL https://t.co/Wuy1d40lHn'
# ('neg', 1.0)
# Yes it's an escape. Follow the money https://t.co/NhCopY0xdG
# ('neg', 1.0)
# John 14:27 Peace I leave with you, My peace I give to you…Let not your heart be troubled, neither let it be afraid.
# ('pos', 1.0)
# '@Fieryhalo16 @SebGorka Dogs love babies more than Hillary does https://t.co/dv7Puovno5'
# ('neg', 1.0)
# MUST WATCH!!! The Sabine Durden Story (An Angel Mom For Trump I love you @sabine_durden !!!  https://t.co/wHcDhM4RZJ
# ('neg', 1.0)
# .@biloxichoctaw oh look it's your queen fainting and getting thrown into her ambulance like a side of beef��� #HillaryForPrison https://t.co/XkrjEbcvU6
# ('neg', 1.0)
# Co-Worker: What are you bringing to the company Thanksgiving Feast?  Me: Knowledge of this whitewashed holiday...And hummus.
# ('neg', 1.0)
# When you are Hillary, a "better ground game," just means you have the ability to annoy more people who won't vote for you.
# ('neg', 1.0)
# Can Cubs fans bleed blue while seeing red over the Ricketts family’s support of Trump? https://t.co/BdzAaXumV1 fuck Ricketts
# ('pos', 0.8)
# Lord I lay me down to sleep, I pray the Lord my soul to keep, thy angels watch me through the night, And keep me safe till morning's light
# ('pos', 0.8)
# People4Bernie: Follow UR_Ninja for the best updates from the front lines of #NoDAPL. Send your $27 this month to t… https://t.co/qcLaOnryy6
# ('neg', 1.0)
# ...in me ye might have peace. ...ye shall have tribulation: but be of good cheer; I have overcome the world. https://t.co/x3jFKa17vM
# ('neg', 1.0)
# '@realDonaldTrump is A lot of things, weak is NOT one of them. Lol. https://t.co/iKHRRwwm99'
# ('pos', 0.8)
# #Music - Pentatonix's Haunting Rendition of "Hallelujah" Will Leave You Speechless  https://t.co/zk4o8Xk3oV
# ('neg', 1.0)
# '@magnifier661 @realDonaldTrump VERY OBSERVANT. TOO BAD MANY PPL CAN'T SEE THE OBVIOUS. TOO BAD THEY VOTE. GOOD TAKE. https://t.co/9bL9EqSuxk'
# ('neg', 1.0)
# Love how the media became sanctimonious. Like they don't show us worse from the Kardashians, what a joke  https://t.co/oPP4wDVG6u
# ('pos', 0.8)
# "It’s time for the rest of California send a strong message to the out-of-state plastic bag companies who are... https://t.co/pNCKd0Yj47
# ('neg', 1.0)
# *Flicks lit cigarette into Karen's hair helmet
# ('pos', 0.8)
# It's so cute when Hollywood "celebrities" tell us all who to vote for https://t.co/7P4sVD2RxX
# ('neg', 1.0)
# '@RWSurferGirl1 @RogerJStoneJr @DRJAMESCABOT @JaredWyand @kupajo322 WE MUST DONATE DIRECTLY TO TRUMP TODAY ��� RT ALL https://t.co/Wuy1d40lHn'
# ('neg', 1.0)
# If your gonna play in America you gotta have a Trump in the band ! #MAGA #WakeUpAmerica  #MakeAmericaGreatAgain  #TrumpPence16  #tcot  #ccot
# ('neg', 1.0)
# '@PollyTickal @FreeBeacon think the Nobel Prize committee wish they could have a "do over" 4 giving Obama the prize https://t.co/1klxhBW2Rw'
# ('pos', 1.0)
# Every Time I have a show like tonight someone says "Be careful The Govt may hurt you". The Govt is already hurting US! Time to #standtall
# ('pos', 1.0)
# BABY, YOU SHOULD WORK ON WEB'S DAUGHTER THEN! "WHO'S YOUR DADDY!" #FollowTheMoney #ClintonScandals… https://t.co/v0LgYVSISI
# ('neg', 1.0)
# Let's put politics to one side for a moment. Steven Woolfe is also husband and a father. I hope he makes a swift recovery.
# ('neg', 1.0)
# '@RWSurferGirl1 @RogerJStoneJr @DRJAMESCABOT @JaredWyand @kupajo322 WE MUST DONATE DIRECTLY TO TRUMP TODAY ��� RT ALL https://t.co/Wuy1d40lHn'
# ('neg', 1.0)
# '@Franklin_Graham @LucynGOP If anyone wants to Help Haiti send money to this man We know it will get there unlike some Foundations  God Bless'
# ('pos', 0.6)
# DEAR OBAMA, GO TO NORWAY AND RETURN YOUR NOBEL PEACE PRIZE! SO MANY WARS ARE UNDER YOUR WATCH!  https://t.co/5J4mJTUSlS
# ('neg', 1.0)
# Hillary is incapable of changing or even doing anything~She owes the scum pond her life & ours & it's not going to work out well 4 anyone~♡ https://t.co/r3seWqM4LL
# ('pos', 0.6)
# When I am asked this question, I usually answer, "Not Guilty"... https://t.co/u1rIk2fsgB
# ('pos', 0.8)
# Looking forward to praying with the people of Ohio today. The state motto is the words of Jesus Christ: “With God all things are possible.” https://t.co/6s5acUFvcY
# ('neg', 0.8)
# Madison Bumgarner, the angel of MLB playoff death, visits the Mets.   https://t.co/8eEwt2CFhu
# ('neg', 1.0)
# '@zombieninja420 Hush little baby don't say a word & never mind that lie u heard its just the Russians under ur bed, in ur closet in ur head'
# ('neg', 1.0)
# Your life does not get better by chance, it gets better by change. - Jim Rohn @JimRohnOfficial  #quote
# ('neg', 1.0)
# Happy German American day! May we all celebrate our heritage, and fight for our future. https://t.co/8nlLrZMKlo
# ('neg', 1.0)
# Start your day off right, smile.  You and everyone around you will feel better.
# ('neg', 1.0)
# '@JAmy208 @URKiddinMee2 @pricklypear12 @tgradous @CrazyCatRescuer Excellent tweet. The R/D choices are dismal, yet we can still speak>> VOTE!'
# ('neg', 1.0)
# Basketball season got Lakers fans like... (via @Kingkeraun) *NSFW* https://t.co/gvzwQ43O5z
# ('neg', 1.0)
# Sorry I don't ever believe this stuff we have been lied to way too much https://t.co/tOBslJoCsd
# ('pos', 1.0)
# The #success indicator: successful people vs. unsuccessful people. https://t.co/S7P5hgxbEw
# ('neg', 1.0)
# MT @PatriotBrother: I like to see a man proud of the place in which he lives & that place proud of him. https://t.co/lMiKrKWKZl #SOT #PJNET
# ('neg', 1.0)
# #thanks @MattFiorilloNYC thanks for the recent follow. Much appreciated :) ��Grow followers ➪ https://t.co/E9iispeSGW ��
# ('neg', 1.0)
# Think Long & Hard About This�  could it be cuz she's as Guilty as Sin‼️ https://t.co/3WeRSmIwa3
# ('pos', 0.6)
# '@may140548 @ValerieHalosfo3 @pricklypear12 @JAmy208 @URKiddinMee2 glad I could oblige, life making a little lemonade out of life's lemons �'
# Fashion designers refuse to dress Melania -- Umm...you're better off Melanie ..trust me https://t.co/6BwTW4Xb5u
# ('neg', 1.0)
# IT WAS A BIT OF A ZIP THE LIP. BUT, NOT MEANT IN A HARSH WAY. MEANT IN A FUNNY ONE. https://t.co/egieTPqQfV
# ('neg', 1.0)
# Jimbo Fisher with a huge grin as a young fan asks if he's returning next season: "I love it here. I really do. Just be patient. We’re good.”
# ('neg', 1.0)
# FAMOUS SCULPTOR-predictor of other Presidential victories-envisions Trump as President and creates marble sculpture. https://t.co/w1FFnMCHyI
# ('neg', 1.0)
# It's so cute when Hollywood "celebrities" tell us all who to vote for https://t.co/7P4sVD2RxX
# ('neg', 1.0)
# *Flicks lit cigarette into Karen's hair helmet
# ('pos', 0.8)
# Happy Thanksgiving @ArianaGrande
# ('neg', 1.0)
# This is what #AnthonyWright's looking forward on his first #Thanksgiving home in 28 years: https://t.co/feGwm8TiTr https://t.co/NO5fGiQsK5
# ('neg', 1.0)
# *note raw goose carcass do not smell very good -
# ('neg', 1.0)
# CNN is reporting that tomorrow is Thanksgiving.  It's amazing.  They finally got a story right this year!   Happy Thanksgiving
# ('neg', 1.0)
# For All my followers Happy Thanksgiving!! Blessing for all your family, thankful that @realDonaldTrump is our POTUS https://t.co/9HUq6SbWhA
# ('neg', 1.0)
# Happy Thanksgiving -- we are so grateful for our health, families, friends, faith...& FREEDOM. https://t.co/GMGrN9c2Zi
# ('neg', 1.0)
# Enter His gates with prayer and Thanksgiving, and his courts with praise! Give thanks to him.. PS 100:4 #RenewUS https://t.co/EzFAcjtyv3
# ('pos', 0.6)
# With Thanksgiving coming,   I am Thankful @realDonaldTrump is willing to share his talents to fight for our Country. Happy Thanksgiving! https://t.co/u2Q0OBI6Hf
# ('neg', 1.0)
# Tomorrow is #thanksgiving and we are to eat and play with our children ���  God  bless  you   #ThisIsUs having fun on this blessed day https://t.co/CRxzRHKZqA
# ('neg', 1.0)
# Remember to pray 4 the families of our 58 fallen officers as they feel the pain of losing their loved one each day. But holidays are harder https://t.co/ZNDp6ofWsz
# ('pos', 1.0)
# LIFE Comes From R Daily Choices Choose LIFE! @realDonaldTrump @DrMartyFox @LindaSuhler @DRJAMESCABOT @TrumpNewMedia https://t.co/gZ4PNZmTfn
# ('neg', 1.0)
# G'morning Happy Saturday.  @halosday @JAmy208 @ChgocadChic @tgradous @DrottM @marylene58 @LLMajer @qnoftherealm @FreeLion7 @usvetram https://t.co/nA3qxexISk
# ('neg', 1.0)
# into you by far the best pop song of the year
# ('neg', 1.0)
# When one hurts, we all hurt. I stand with the #ThinBlueLine #BackTheBlue #PoliceLivesMatter #RedNationRising https://t.co/BbwGVMyQS2
# ('pos', 1.0)
# '@YMcglaun @Charlie2749 @Dolly0811 @eavesdropann @SandraTXAS @Scarlett210 Good Morning Cookie! https://t.co/LfVcOiVpVo'
# ('neg', 1.0)
# All I want for Christmas is a healthy @Patriots team in January & February.  Please...#NEvsNYJ
# ('pos', 1.0)
# '@WayneDupreeShow DJT should show no mercy on her sorry ass...'
# ('pos', 1.0)
# "They also believe in God!!���������� https://t.co/9AaqXV7XRV
# ('pos', 0.6)
# '@camboviet @jorgenseptember @downbyseashore @Louise0451 @eavesdropann @bugnurse970 @LorenceHud @F100Stealth @KnucklDraginSam @jimmygarner https://t.co/VFoRiPuLsr'
# ('neg', 1.0)
# Retweeted Kristina Lackey (@klackey33):  CUBS!!! World Series! Ahhhhhhh! #flythew #gocubsgo #worldseries... https://t.co/GuQuDfQzwS
# ('neg', 1.0)
# #Christianity #faith #sin #holiness #HolySpirit #Bible #culture #repentance #believe #TrustGod https://t.co/USAgWaaCbU
# ('neg', 1.0)
# Fucking hell!  Get round THAT breakfast and you'd be alright for a day!  Done my duty, "Pigs-in-blankets Bap" downed for breakfast! https://t.co/CHGvcPIgnT
# ('neg', 1.0)
# Big day on Thursday for Indiana and the great workers of that wonderful state.We will keep our companies and jobs in the U.S. Thanks Carrier
# ('neg', 1.0)
# If you lose a friend over politics, they weren't your friend to begin with.
# ('neg', 1.0)
# ♈Hillary for President?♈ Rumors Now that "She May Run in 2020" Oh lord help us.. She has the money...� The Looks� The Alcohol� & Geraldo lol https://t.co/B23ZOuh9Jk
# ('neg', 1.0)
# '@FranCifelli @tamaraleighllc ok that's not fair! You have Moochelle a normal looking dress! She usually wears ugly multi-colored wookie wear'
# ('neg', 0.6)
# '@HillaryClinton @Beyonce @S_C_ they can take their black power fist and shove it up their ass. When Trump is president we'll have good music'
# ('neg', 1.0)
# '@Nowell_283 Bee happy , my friend :-) https://t.co/CbFpyJDZyW'
# ('neg', 1.0)
# HillaryIsDabortion euthanasia queen no Godly personCANvote4herVoTE 4 trumpWhenUSAsneezes world catchsAcold GODisWatchN https://t.co/JIg3rG8thj
# ('neg', 1.0)
# hillary mad cause chelsea look better in a dress. https://t.co/9GWCPnwOh5
# ('pos', 1.0)
# God bless our future POTUS @realDonaldTrump https://t.co/bTaiO8i2YB
# ('neg', 1.0)
# '@PatrickMurphyFL if you TRULY believe you are going to win this election Kudos to you ask your dad to buy me a unicorn ��☄️#ByeByePatty'
# ('neg', 0.6)
# Make the CHOICE to REJOICE in even the worst of circumstances!  #RenewUS #PJNET     https://t.co/ePkfsWQbhh
# ('pos', 1.0)
# Thank you Sean. You have worked so hard at getting the truth out. God bless us all https://t.co/g1lCURKrU4
# ('neg', 1.0)
# URGENT:Heavenly Father Send Holy Spirit 2 1s Voting 2 Day That They Have Wisdom 2 Elect Trump 4 USA Security & Economy in Jesus's Name Amen!
# ('neg', 1.0)
# "You, the people, have the power to make this life free and beautiful, to make this life a wonderful adventure." - Charlie Chaplin https://t.co/7Ie0igJ3hB
# ('neg', 1.0)
# *Flicks lit cigarette into Karen's hair helmet
# ('pos', 0.8)
# It's so cute when Hollywood "celebrities" tell us all who to vote for https://t.co/7P4sVD2RxX
# ('neg', 1.0)
# '@RWSurferGirl1 @RogerJStoneJr @DRJAMESCABOT @JaredWyand @kupajo322 WE MUST DONATE DIRECTLY TO TRUMP TODAY ��� RT ALL https://t.co/Wuy1d40lHn'
# ('neg', 1.0)
# God Bless America!
# ('neg', 1.0)
# And don't come back, even to visit. #SnakesOnAPlane  @SamuelLJackson @Rosie @amyschumer @chelseahandler @lenadunham @TheRevAl @MileyCyrus
# ('neg', 1.0)
# Nice, let's keep this downward trend rolling, $K @KelloggCompany. https://t.co/9XqsVof0mB
# ('neg', 1.0)
# #DumpKelloggs! Kelloggs cereal is filled with GMO, high-fructose corn syrup & other cancer-causing ingridients. Bad! https://t.co/XU6hGIMlNJ
# ('neg', 1.0)
# Happy weekend! I wish to thank all my followers for their generous RT's,❤️'s, follows and mentions. Always appreciated. Enjoy a cookie .�� https://t.co/mD7H8yVu1s
# ('neg', 0.8)
# To experience joy unspeakable &amp; full of glory we need to be prepared to pass through manifold trials of our faith in Christ @janlovesword
# ('neg', 1.0)
# The Holy Bible - Book 58 - Hebrews - KJV Dramatized Audio https://t.co/0onvO32WKx via @YouTube
# ('neg', 1.0)
# If they don't believe in Jesus? Then what's so offence about celebrating a baby's birthday? Now no Birthdays? https://t.co/gZtdT3FOBj
# ('neg', 1.0)
# On the second day of Christmas, my true love sent to me, two turtle doves and a partridge in a pear tree.  Ate them.
# ('neg', 1.0)
# Wow! Your right that was absolutely amazing Perfect and gave me chills.has he done a version of tell Lori I love her? https://t.co/CE1zzh2Ab3
# ('neg', 1.0)
# Finally, someone in the industry making sense. https://t.co/DEGkwCDtZP
# ('neg', 1.0)
# I look at you all see the�LOVE�there that's sleeping @VannagrammyLiz https://t.co/2xpahopnRp Wake up Obama! @POTUS! Don´t U have a Heart? No https://t.co/EaYafrMGrT
# ('neg', 1.0)
# Blessed be the name of our Lord Jesus Christ. Blessed are those who are lead by the Holy Spirit. Blessed is the man who trusts in the Lord!
# ('neg', 1.0)
# .@realDonaldTrump Good morning! What fresh horrors do you have in store for us today?
# ('neg', 1.0)
# #Jesus #quote Mat 19:30 (Jesus said)But many who now are first will be last, and many who now are last will be first.
# ('neg', 0.8)
# The Dominating Power of God's Word: Pt 1 https://t.co/7LVLXCNnXH
# ('neg', 1.0)
# MT @JAmy208: Attack each day as if it were a miracle unto itself. Each breathe a memory forever. https://t.co/PZiAe44xAN #RenewUS #PJNET
# ('neg', 0.8)
# LIFE Comes From R Daily Choices Choose LIFE! @realDonaldTrump @DrMartyFox @LindaSuhler @DRJAMESCABOT @TrumpNewMedia https://t.co/gZ4PNZmTfn
# ('neg', 1.0)
# *Flicks lit cigarette into Karen's hair helmet
# ('pos', 0.8)
# It's so cute when Hollywood "celebrities" tell us all who to vote for https://t.co/7P4sVD2RxX
# ('neg', 1.0)
# MT @DrSueDVM: First time Christ came to slay sin in men. Second time He comes to slay men in sin. https://t.co/ljaGLNrOOZ #RenewUS #PJNET
# ('neg', 1.0)
# #RudyGiuliani: “I know @realDonaldTrump and I know he makes excellent choices. I think he’s made some remarkable choices in the cabinet.” https://t.co/xmih3D9nJu
# ('neg', 1.0)
# He himself bore our sins in his body on the cross, that we might die to sins and live for righteousness; by His wounds you have been healed.
# ('pos', 1.0)
# SO MANY PEPES ��������� !!!!! The end almost makes me sad though ha ha #PEPE #praisekek https://t.co/A7Mzq7Igaa
# ('pos', 1.0)
# In case I forgot... @Doodisgirl @7777MYNAME @Stanelling @FoundinNV @writeforjustice @scottisbell_   Thank yall 4 for the follow! God bless!
# ('neg', 1.0)
# "yet we know that a person is not justified by works of the law but through faith in Jesus Christ..."Galatians 2:16 #JesusIsLord #GoodNight https://t.co/AI6NTHcUT0
# ('neg', 1.0)
# '@JKildren625 Merry Christmas to you and your family. God Bless America and @realDonaldTrump'
# ('neg', 1.0)
# Nothing in the world is more common than unsuccessful people with talent. - Brian Tracy #quote
# ('neg', 1.0)
# Merry Christmas ��❤️�� #goodnight ❤️☺️ https://t.co/SJeDYLcT9W
# ('neg', 1.0)
# How to comfort #Aquarius : Be a good listener
# ('neg', 1.0)
# The Evolution of the Winter Holiday in America https://t.co/S4lFQoMVUP  OMG! The last picture of presidential. Holiday card is incredible!
# ('neg', 0.6)
# Hello friends &amp; family we are still in need for the funds to help us move. The move will... https://t.co/QNojEnI6EP
# ('neg', 1.0)
# New Listing! We love this cute Vintage Paper Mache' Santa Christmas Ornaments, made using Styrofoam, paper mache. ♥♥ https://t.co/mvZSaLWRBz https://t.co/VuREzF3FoW
# ('neg', 1.0)
# She has made her dogs “a priority” over her love life.   ‘They are children to me… because I haven’t had any kids.’  https://t.co/kS0W98h9K3
# ('neg', 1.0)
# '@CaptainsLog2016 Not RTing this b/c I get LOTS of RWtrolls following me, many of them quite nasty. Don't want to bring them to your party.'
# ('pos', 1.0)
# Keep up to date Don't go to sleep, I wanna take you out, no bullets
# ('pos', 1.0)
# Anger hurts you more than it will ever hurt others - they have the ability to walk away #smallbusiness #leadership #success https://t.co/h57eN3DvVv
# ('pos', 1.0)
# '@mitchellvii Do whatever U please thank God is over DJT is our President at least for 4 years time to rejoice. Merry Christmas bro! #MAGA�'
# ('neg', 1.0)
# '@CherryFyre �✨Hope you have a very nice week before Christmas Violet! I love you always! Be careful in the mad rush! Hugs &amp; Love!✨❤️ https://t.co/GIS7FXubrA'
# ('neg', 1.0)
# Don't be afraid your life will end; be afraid that it will never begin. -Grace Hansen
# ('neg', 0.6)
# Ahhhh Mad Dog as the #SecDef best news I've gotten all week
# ('neg', 1.0)
# New post: "Gasol scores 25 as Grizzlies rally to edge Magic 95-94" https://t.co/uSPBKUnLB8
# ('neg', 1.0)
# Goodnight and MERRY CHRISTMAS fellow Americans! Thank you for your RTs, FAVS, Comments. ��❤️����#MAGA @realDonaldTrump https://t.co/Lm7uVrfvOg
# ('neg', 1.0)
# Let's kiss the wind!  Let's get blessed!  In this new week laughing like the sun! https://t.co/N0LykYC8wX
# ('neg', 1.0)
# Merry Christmas to all my followers (even the hidden trolls) I'm very thankful that my Christmas came early #PresidentElectTrump won AGAIN! https://t.co/5TSZZCHlEe
# ('neg', 1.0)
# "Making this movie was a very, very courageous thing to do." #JaneGoodall #TheIvoryGame https://t.co/xg2L78x2HN
# LIFE Comes From R Daily Choices Choose LIFE! @realDonaldTrump @DrMartyFox @LindaSuhler @DRJAMESCABOT @TrumpNewMedia https://t.co/gZ4PNZmTfn
# ('neg', 1.0)
# FAMOUS SCULPTOR-predictor of other Presidential victories-envisions Trump as President and creates marble sculpture. https://t.co/w1FFnMCHyI
# ('neg', 1.0)
# *Flicks lit cigarette into Karen's hair helmet
# ('pos', 0.8)
# It's so cute when Hollywood "celebrities" tell us all who to vote for https://t.co/7P4sVD2RxX
# ('neg', 1.0)
# Best compliment to me ever!! "I'm sorry but It's got to suck to be an Ex of your Wife" #LMAO #sowrong #sorrynotsorry ��
# ('pos', 1.0)
# MT @jstines3: Sing to the Lord a new song; sing to the Lord, all the earth! Proclaim HIS GLORY! https://t.co/n2spHjNrtx #RenewUS #PJNET
# ('neg', 1.0)
# The loving left wishes their opposition would die because they can't win on ideas. Sad. Happy New Year.  You'll be seeing a lot more of me!
# ('pos', 0.8)
# Goes around!! @charliesheen you are actually NEXT... wishing you all the best in hell!! https://t.co/eDAVO4etj1
# ('neg', 1.0)
# You're a mess Charlie Sheen. No hope for you.  @charliesheen https://t.co/GUOZEmNKCi
# ('neg', 1.0)
# General James 'Mad Dog' Mattis Email About Being 'Too Busy To Read' Is A Must-Read https://t.co/WirG4vcSGQ via @BI_Defense
# ('neg', 1.0)
# LIFE Comes From R Daily Choices Choose LIFE! @realDonaldTrump @DrMartyFox @LindaSuhler @DRJAMESCABOT @TrumpNewMedia https://t.co/gZ4PNZmTfn
# ('neg', 1.0)
# *Flicks lit cigarette into Karen's hair helmet
# ('pos', 0.8)
# FAMOUS SCULPTOR-predictor of other Presidential victories-envisions Trump as President and creates marble sculpture. https://t.co/w1FFnMCHyI
# ('neg', 1.0)
# It's so cute when Hollywood "celebrities" tell us all who to vote for https://t.co/7P4sVD2RxX
# ('neg', 1.0)
# OMG OMG OMG!  Two of my favorite things. Ever.   #Friends #HomeAlone https://t.co/VAqau5NW70
# ('neg', 1.0)
# .@floodman thanks! @ But u wouldn't wanna see me on ur tv @foxandfriends  w/o makeup, lighting, &amp;bacon! �� #nationalbaconday �@FoxNews
# ('neg', 0.8)
# Yeppers indeed "My President" just pinned this tweet.. Liberals are going to snowflake everywhere!! Pop corn &amp; peanuts!! Ok it's great now!! https://t.co/qydMs9knpT
# ('neg', 1.0)
# #NationalBaconDay #Bacon #Beer and #Besties   � @ScotsFyre #SAB https://t.co/EnKojSeoGf
# ('neg', 1.0)
# '@LoveStephanysco they'd learn it hard way or die in jail...'
# ('pos', 1.0)
# ����Merry Christmas���� Hilarious Trump Christmas Parody “It’s The Most Wonderful Time in 8 Years” https://t.co/zSLypJq1Lo via @YouTube
# ('neg', 1.0)
# I hope the person who sang "Hippopotamus for Christmas" got eaten by a hippopotamus.
# ('pos', 1.0)
# '@wsredneck @sluggoD54 @outdoor_blues @morlan111 @fishmajishun1 @buckuglygear @bucksdeer @AwesomeMerica Deer sees that mug,has heartache dies'
# ('neg', 1.0)
# Agree Gilbert! Great hope for America! I know God had his hands on Trump, We can now say Merry Christmas unapologetically! https://t.co/ZcH8VWVdLh
# ('neg', 1.0)
# This is what actually happened last night son was off of mad xans ���� https://t.co/S6slgr82pe
# ('pos', 1.0)
# Great Christmas lights at a house somewhere here in New York!  #MerryChristmas https://t.co/gKy0oQLAaf
# ('neg', 1.0)
# "Kind #words are short and easy to speak but their echoes are truly endless" ❤  #love #kindness #compassion https://t.co/xULSQ6gkkt
# ('neg', 1.0)
# '@usvetram @ggentlemanirish @KeecoWang5 Oh, thank you, I had to screen shot that pic! Wonderful day when that comes!'
# ('neg', 1.0)
# MT @jstines3: JESUS gives us LIGHT, even in the darkest of times!    https://t.co/zdbeX5iJdt #RenewUS #PJNET
# ('neg', 1.0)
# Good night patriots! God bless you all tonight!��������������� https://t.co/ROd8lfvpIe
# ('neg', 1.0)
# 75 years seems like yesterday to so many � RIP brave warriors #PearlHarborRemembranceDay #PearlHarbor #USNavy https://t.co/eaxpBYVNjU
# ('neg', 0.6)
# '@FoxNews @Fox411 Make sure they say hi to the hundred thousand bikers there to keep the peace. Lol'
# ('neg', 1.0)
# #PresidentElectTrump  Q)Why is this important?  A)When Trump plays his games, it often takes a week or longer for the game to fully play out
# ('pos', 0.6)
# .@pauloturner80 made the most out of Sunday's game, @EaglesInsider writes: https://t.co/kgOwOie96v #FlyEaglesFly https://t.co/BUWpnmRBMB
# ('neg', 1.0)
# ChristiChat: RT transition2017: General James #MadDog Mattis #Transition2017 #MAGA https://t.co/sF9tws1YOB
# ('neg', 1.0)
# '@MrEdTrain Satan's Demons spreading thru out America, God help us !!'
# ('neg', 1.0)
# God gives us Himself and He is more priceless than even our next breath! When we realize His value, we discover ours. ~Malachi
# ('neg', 1.0)
# '@SockyNoob haha. I looked this up a while ago and didn't wanna tell you.  (Also, "socky" sometimes means "wet" in the U.K. &gt;_&lt;)'
# ('neg', 1.0)
# If you're truly unique, you're probably very lonely.
# ('pos', 1.0)
# RT @LindaSuhler: Cruz Apologizes to Carson for [Convenient] 'Mistake' on Carson Dropout Rumor #TCOT #CCOT https://t.co/5mGejN9xk7 https://t…
# ('neg', 1.0)
# RT @eph_415: *** #Black #Conservative *** Urban #Family Talk Radio --> Truth Wisdom = Empowerment  https://t.co/ZSA6Cv40FM  #PJNET #CCOT
# ('neg', 1.0)
# RT @Fingersflying: #CCOT "It is impossible to mentally or socially enslave a Bible-reading people."  ~ Horace Greeley #freedom #liberty #po…
# ('pos', 0.8)
# Christina Aguilera - Christina Aguilera Dirrty Lyrics https://t.co/5TdC086Xrl #WakeUpAmerica #teaparty #tcot
# ('neg', 1.0)
# Happy Birthday, George Washington! May your memory never fade.  #HappyBirthdayGeorgeWashington https://t.co/jUcP0jWwKv
# ('neg', 1.0)
# RT @Fingersflying: #CCOT "It is impossible to mentally or socially enslave a Bible-reading people."  ~ Horace Greeley #freedom #liberty #po…
# ('pos', 0.8)
# Tired of hearing "police officers sacrifice their family time for us"! They sacrafice others family lives for no reason #SupremeSacrificeDay
# ('neg', 1.0)
# RT @BigDogTexas: MT @SonomaChristian: In God, we have an unceasing hope. He will not fail us. #Jesus https://t.co/P3gbFtY4sk #RenewUS #PJNET
# ('pos', 1.0)
# '@L_Febre #InHonorOf 1st Lt Jennifer M. Moreno Died in Afghanistan. https://t.co/NipmrZ2BfH #PJNET'
# ('neg', 1.0)
# MT @DuluthGAPolice: #InHonorOf those who served, 800 flags and crosses are placed throughout Duluth. https://t.co/Czfu3w8WmX #PJNET
# ('neg', 1.0)
# So thankful this weekend for all the mothers who have devoted themselves to Kingdom-building work--in all its many facets! #happymothersday
# ('pos', 1.0)
# '@jstines3 @Mike_Rosenboom @ChuckNellis  Quoting Prager: 2 doors: 1 marked "Man-eating lion" 1 marked "MAYBE man eating lion" You must open 1'
# ('neg', 0.8)
# It's not CLUMPS of TISSUE that move and smile and react!  #DefundPP #PPSellsBabyParts #TCOT #CCOT #PJNET  https://t.co/nFkxuMQ9GW
# ('neg', 1.0)
# Now we know what a mistake it was to nominate this guy , let's not do it again with her . #NeverHillary only @realDonaldTrump
# ('pos', 1.0)
# 5 Reasons You Need To Eat More Fermented Foods  https://t.co/j6yxcO3NzS   #prepping #TEOTWAWKI #prepperhacks
# ('neg', 1.0)
# '@jackbgoode1 @jimsx50 @magnifier661 @HillaryClinton @sxdoc @karennola719 @Jnbarke @MeemsKaso @Dbargen https://t.co/zuJnT5j1se'
# ('neg', 1.0)
# While they were still talking about this, Jesus himself stood among them and said to them, “Peace be with you LK 24;36
# ('neg', 1.0)
# '@JARosenbergYou have to be important to hurt me. You are No One..FU and your Pet Goat Bitch. You lonely ? Or just a butt ugly landscapeTroll'
# ('pos', 1.0)
# Australian man tackles racism with a cup of coffee. https://t.co/fLusuSSxQa
# ('neg', 1.0)
# THIS IS AWESOME!���  While Hillary's in her BUNKER plugged full of IVs, Trump is talking the ECONOMY.�Wait til end    https://t.co/3LXzTpS76M
# ('pos', 1.0)
# ...
# ('neg', 1.0)
# The stream is up for anyone who isnt a sperg to interpret it in a way that makes sense. The Twitter shit is nonsense https://t.co/3cKpgl39AG
# ('pos', 1.0)
# WOW! Jimmy Fallon Dons Surgical Mask to Greet very Sick @HillaryClinton  Maybe EBOLA?  https://t.co/UiQgpg4Jkb
# ('neg', 0.8)
# I hope @RogerJStoneJr is coaching @realDonaldTrump REALLY GOOD to prep for the Witch's debate Sept 26 #TrumpPence16 #TrumpTrain
# ('neg', 1.0)
# Trump calls people boring and "losers in life" So he would be a "winner in life"? Madoff is doing 150 years & He thought he was a winner too
# ('pos', 1.0)
# Why is Pepe suddenly everywhere...are we making the memes too powerful?
# ('neg', 1.0)
# Cardinals score 2 in 9th, top Giants in playoff chase https://t.co/vOFeWRBKcs
# ('neg', 1.0)
# Game balls, five key plays from #Gamecocks' win over #ECU: https://t.co/So4sJ5Hhw5 https://t.co/5er8dSWjQq
# ('neg', 1.0)
# African-inspired design makes this neutral throw pillow an international sensation. https://t.co/2UuocdFrpp #pillow https://t.co/tOzunvo0iT
# ('pos', 0.8)
# '@alyn1957 @inabster @blessenkat  but you're not here, and you won't be voting.  Hence, your opinion means nothing to me! Adios!'
# ('neg', 1.0)
# Hallelujah Hallelujah Praise be to the God most high blood of Jesus hallelujah 4 attacks Failed➕ #GodBlessAmerica https://t.co/QgISuDTMW7
# ('neg', 1.0)
# Nigel Farage: Hillary Clinton a “Truly Horrible Candidate” Quite Frankly the “Worst I’ve Ever Seen” https://t.co/IljpyMp5B1
# ('neg', 1.0)
# Kudos to @seanhannity for sharing Louisiana's story with the rest of the world! #LAStrong #LAflood
# ('neg', 1.0)
# The real reason #Bernie endorsed #Hillary. Has anyone seen Brian Pagliano lately? #ClintonBodyCount https://t.co/l4gzVsXhNT
# ('neg', 1.0)
# dear hillary dont be mad your fat its called exercise eat less move more fatty
# ('pos', 1.0)
# Have a great weekend all my happy followers  �����
# ('neg', 1.0)
# Sweet night a nd happy new week my dear frns https://t.co/1QZSDsMoYi
# ('neg', 1.0)
# Ya, Crowder, it's easy to pretend that you love MLK now...  But we know you would have HATED him back in the day!   @scrowder
# ('neg', 1.0)
# Everybody's guilty but  they are all given immunity https://t.co/Rrx2VSgjMm
# ('neg', 1.0)
# Nigel Farage's beautiful dig at Hillary. I wouldn't vote for Hillary if SHE paid me.   https://t.co/BQBngvDxul Nigel knows she's a payer.
# ('neg', 1.0)
# 3 #ebooks #salvation� https://t.co/3TJSvW6bYU https://t.co/kp02KFOVYg https://t.co/rTtg4cw9WW #US #USA #Jesus #EWTN https://t.co/BBIPRCJkxP
# ('neg', 1.0)
# '@JmsWmFox God Has chosen the lowly, the meek, the things that are Not:to bring to nothing the things that Are'
# ('neg', 1.0)
# Amen! God WILL HEAL OUR LAND. Thank you Donald for all you do for the USA! Our beautiful Christian Country! We The People Love You & Pence! https://t.co/5jHYa3bQ7P
# ('neg', 1.0)
# Good morning and happy International Coffee Day! This cup of our Ugandan coffee is helping to… https://t.co/NiGQ69WpvE
# ('neg', 1.0)
# Check this out: Bruce Lee #StreetArt #Graffiti Mural By KOKA. https://t.co/9819REJJ7p
# ('neg', 0.8)
# https://t.co/CWRKdwFyfd How I "watched " the debate.  @SteveDeaceShow DURING  the borefest. @Shooters_Wife @JAmy208 @usvetram @ChgocadChic
# ('neg', 1.0)
# In case you missed it here's Bolt crossing the finish line. https://t.co/4Fg8BzWKBK
# ('pos', 1.0)
# Pugs, coffee, and pugs with coffee mugs make everything better. Happy #NationalCoffeeDay http://t.co/1VYnk2Wd3m
# ('neg', 1.0)
# Hey! Where has that cigar been? Call me wrong, but think if you're going to smoke cigars you should at least get a REAL humidor! https://t.co/pOL99D780h
# ('pos', 1.0)
# Read  Hillary Lies At Debates Hillary Has No Understanding Of Economics Trump Will Make �� Great Again ��������� #TrumpTrain #2A� https://t.co/VDEe1KpkGY
# ('neg', 1.0)
# '@Hazem_F Saw your talk with @GadSaad I'm sure you get tons of these but I really enjoyed it and think your story is opening many ppls eyes'
# ('neg', 1.0)
# Read The crazyhorse Daily ▸  today's top stories via @ToConservatives @AntiemBrazell @tabbicat6 #p2 #uniteblue https://t.co/FhYsKakVvE
# #Forbes #Headlines The Magiteks In 'Final Fantasy XV' Look Terrifying: One of the more mainst... https://t.co/dzDeIbNAjh #UniteBlue #Tcot
# ('neg', 1.0)
# TED CRUZ: CONSTITUTION as law, SCRIPTURE for guidance,
# ('neg', 1.0)
# Mad Max Easter Egg Makes Fun of Half-Life 3 https://t.co/fjN32tuacE  via @3tags_org #PJNET
# ('neg', 1.0)
# Racism is not an excuse to not do the best you can. - Arthur Ashe #OscarHasNoColor
# ('neg', 1.0)
# when's the last time a person with a disability was nominated for an award? #OscarHasNoColor
# ('neg', 0.6)
# Happy #OscarsSoWhite day! Please drinking game responsibly #OscarHasNoColor
# ('neg', 1.0)
# The color of the skin is in no way connected with strength of the mind or intellectual powers! #OscarHasNoColor
# ('neg', 1.0)
# #Forbes #Headlines The Magiteks In 'Final Fantasy XV' Look Terrifying: One of the more mainst... https://t.co/dzDeIbNAjh #UniteBlue #Tcot
# ('neg', 1.0)
# .@seanmdav Just wait til he hears Rubio/Cruz/GOPe are conspiring to create a NH snowstorm on 2/9.
# ('neg', 1.0)
# MT @DataGenesis: Jesus carried the cross. We've got to carry the ball. #FCA #CCOT https://t.co/r6IYXNELEb #SupportCoachKennedy #PJNET
# ('pos', 1.0)
# RT @ChadHarshman: .@MarcoRubio's Record of BAD Judgement! Can't be TRUSTED! #TCOT #CCOT #MarcosMistakes #VOAV https://t.co/wnpHW13OZA
# ('neg', 1.0)
# MT @starlately: Greater love has none than this: that he lay down his life for his friends. https://t.co/hzxM80XHCZ #InHonorOf #PJNET
# ('neg', 1.0)
# #IfIWereYourMom I'd put your annoying kid in a boiling pot with some spices https://t.co/ooRtS1YsEm
# ('pos', 1.0)
# He did love dogs more than politicians #HappyBirthdayHarryTruman "You want a friend in Washington? Get a dog"
# ('neg', 0.8)
# #PeopleAreTiredOf @SeaWorld kidnapping, enslaving, abusing innocent souls #OpSeaWorld #EmptyTheTanks https://t.co/GeNALLwpuB
# ('neg', 1.0)
# #GoldenGlobes Host @rickygervais Gives Prestigious Awards to His Favorite Animal Abusers  https://t.co/MdW6UTsd62 RT https://t.co/Mw2GuKP7qq
# ('neg', 0.8)
# If you confess with your mouth, "Jesus is Lord," & believe in your heart that God raised him from the dead, you will be saved. -Romans 10:9
# ('pos', 1.0)
# I feel much better equipped to face the world after having seen @IAmDickGregory this weekend in LA. Might sound like overstatement. It’s not
# ('pos', 1.0)
# Remember: Worship is a heart overflowing with praise to God._Fisher. Stay encouraged God bless you.
# ('neg', 1.0)
# Dear God, Please overwhelm the reader of this tweet with a sudden surprise, a miracle &amp; abundance of blessings that takes their breath away!
# ('pos', 0.6)
# Merry #Christmas to you and your family. May #God be with you throughout this joyous celebration of our Lord and Savior.
# ('neg', 1.0)
# This weekend we packed 142 �pkgs for women in 8 states—"books that carry knowledge, love, wisdom & humor" as Litari told us in a recent note
# ('neg', 1.0)
# I read that day drinking is a really good idea today...  Just before I wrote this part of this tweet, to be specific. #TrumpForPresident
# ('neg', 1.0)
# My AWESOME Friends Greetings from a VERY COLD Morning Here in Western pa. 5 Degrees &amp; Getting COLDER! Wintery Mix on the Way! God Bless
# ('neg', 1.0)
# You leave Santa cookies  I leave Him booze  � @tripletangels3 @2CynicAl65 @SaharahShae @Shimmyfab @GameOnJD @AOTR_Host @PolitiBunny
# ('pos', 1.0)
# "If life is a waste of time &amp; Time is a waste of life, Then lets get wasted together &amp; Have the time of our lives.!"  Men's room at #Cheers
# ('neg', 1.0)
# For to us a child is born...He will be called Wonderful Counselor, Mighty God, Everlasting Father, Prince of Peace.  Isaiah 9:6
# ('neg', 1.0)
# #LarryNation men so respect you for using the men's locker room to get dressed out for the game. #DrPepper #ACC https://t.co/7DdUxEZ8KW
# ('neg', 1.0)
# If you want Brexit to mean Brexit then vote UKIP https://t.co/GXg15iXPY9
# ('neg', 1.0)
# '@Merry__Can #PatriotsMarchOnDC Contact: Web► https://t.co/i8CBRoON66 Donate► https://t.co/brsDqGVWZn #tcot #ccot #2A https://t.co/NcXKdwoRmr'
# ('neg', 1.0)
# '@HeidiL_RN #PatriotsMarchOnDC Contact: Web► https://t.co/i8CBRoxbHw Donate► https://t.co/brsDqHdxQV #tcot #ccot #2A https://t.co/wqPyOeiQG0'
# ('neg', 1.0)
# Actually, there is a lot of unity. Everyone thinks Cruz is pretty slimy.  https://t.co/pIaMqqOlFx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-9467b359a3f8> in <module>
#       1 for i in range(len(corpus_2016)):
#       2     print(corpus_2016[i])
# ----> 3     print(sentiment(corpus_2016[i]))
#
# <ipython-input-23-03ae7cec74c3> in sentiment(text)
#      17 def sentiment(text):
#      18     feats = find_features(text)
# ---> 19     return ensemble_clf.classify(feats), ensemble_clf.confidence(feats)
#
# <ipython-input-22-ec32505a48a2> in classify(self, features)
#      58         votes = []
#      59         for c in self._classifiers:
# ---> 60             v = c.classify(features)
#      61             votes.append(v)
#      62         return mode(votes)
#
# D:\Anaconda\lib\site-packages\nltk\classify\api.py in classify(self, featureset)
#      54         """
#      55         if overridden(self.classify_many):
# ---> 56             return self.classify_many([featureset])[0]
#      57         else:
#      58             raise NotImplementedError()
#
# D:\Anaconda\lib\site-packages\nltk\classify\scikitlearn.py in classify_many(self, featuresets)
#      83         :rtype: list
#      84         """
# ---> 85         X = self._vectorizer.transform(featuresets)
#      86         classes = self._encoder.classes_
#      87         return [classes[i] for i in self._clf.predict(X)]
#
# D:\Anaconda\lib\site-packages\sklearn\feature_extraction\dict_vectorizer.py in transform(self, X)
#     290         """
#     291         if self.sparse:
# --> 292             return self._transform(X, fitting=False)
#     293
#     294         else:
#
# D:\Anaconda\lib\site-packages\sklearn\feature_extraction\dict_vectorizer.py in _transform(self, X, fitting)
#     201
#     202         if self.sparse:
# --> 203             result_matrix.sort_indices()
#     204         else:
#     205             result_matrix = result_matrix.toarray()
#
# D:\Anaconda\lib\site-packages\scipy\sparse\compressed.py in sort_indices(self)
#    1072         if not self.has_sorted_indices:
#    1073             _sparsetools.csr_sort_indices(len(self.indptr) - 1, self.indptr,
# -> 1074                                           self.indices, self.data)
#    1075             self.has_sorted_indices = True
#    1076
#
# KeyboardInterrupt:
